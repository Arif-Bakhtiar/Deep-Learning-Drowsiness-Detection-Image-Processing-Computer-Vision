# %%
# This Python 3 environment comes with many helpful analytics libraries installed
# It is defined by the kaggle/python Docker image: https://github.com/kaggle/docker-python
# For example, here's several helpful packages to load

import numpy as np # linear algebra
import pandas as pd # data processing, CSV file I/O (e.g. pd.read_csv)
import os
import cv2

# %% [markdown]
# # labels

# %%
labels = os.listdir("../input/drowsiness-dataset/train")

# %%
labels
# Out:
# ['Closed', 'Open', 'yawn', 'no_yawn']

# %% [markdown]
# # visualize random 1 image

# %%
import matplotlib.pyplot as plt
plt.imshow(plt.imread("../input/drowsiness-dataset/train/Closed/_10.jpg"))

# %% [markdown]
# # image array

# %%
a = plt.imread("../input/drowsiness-dataset/train/yawn/10.jpg")

# %% [markdown]
# # image shape

# %%
a.shape
# Out:
# (480, 640, 3)

# %% [markdown]
# # visualize yawn image.
# # Here background is unnecessary. we need only face image array

# %%
plt.imshow(plt.imread("../input/drowsiness-dataset/train/yawn/10.jpg"))

# %% [markdown]
# # for yawn and not_yawn. Take only face

# %%
def face_for_yawn(direc="../input/drowsiness-dataset/train", face_cas_path="../input/prediction-images/haarcascade_frontalface_default.xml"):
    yaw_no = []
    IMG_SIZE = 145
    categories = ["yawn", "no_yawn"]
    for category in categories:
        path_link = os.path.join(direc, category)
        class_num1 = categories.index(category)
        print(class_num1)
        for image in os.listdir(path_link):
            image_array = cv2.imread(os.path.join(path_link, image), cv2.IMREAD_COLOR)
            face_cascade = cv2.CascadeClassifier(face_cas_path)
            faces = face_cascade.detectMultiScale(image_array, 1.3, 5)
            for (x, y, w, h) in faces:
                img = cv2.rectangle(image_array, (x, y), (x+w, y+h), (0, 255, 0), 2)
                roi_color = img[y:y+h, x:x+w]
                resized_array = cv2.resize(roi_color, (IMG_SIZE, IMG_SIZE))
                yaw_no.append([resized_array, class_num1])
    return yaw_no


yawn_no_yawn = face_for_yawn()
# Out:
# 0
# 1

# %% [markdown]
# # for closed and open eye

# %%
def get_data(dir_path="../input/drowsiness-dataset/train/", face_cas="../input/prediction-images/haarcascade_frontalface_default.xml", eye_cas="../input/prediction-images/haarcascade.xml"):
    labels = ['Closed', 'Open']
    IMG_SIZE = 145
    data = []
    for label in labels:
        path = os.path.join(dir_path, label)
        class_num = labels.index(label)
        class_num +=2
        print(class_num)
        for img in os.listdir(path):
            try:
                img_array = cv2.imread(os.path.join(path, img), cv2.IMREAD_COLOR)
                resized_array = cv2.resize(img_array, (IMG_SIZE, IMG_SIZE))
                data.append([resized_array, class_num])
            except Exception as e:
                print(e)
    return data

# %%
data_train = get_data()

# %% [markdown]
# # extend data and convert array

# %%
def append_data():
#     total_data = []
    yaw_no = face_for_yawn()
    data = get_data()
    yaw_no.extend(data)
    return np.array(yaw_no)

# %% [markdown]
# # new variable to store

# %%
new_data = append_data()
# Out:
# 0
# 1
# 2
# 3

# %% [markdown]
# # separate label and features

# %%
X = []
y = []
for feature, label in new_data:
    X.append(feature)
    y.append(label)

# %% [markdown]
# # reshape the array

# %%
X = np.array(X)
X = X.reshape(-1, 145, 145, 3)

# %% [markdown]
# # LabelBinarizer

# %%
from sklearn.preprocessing import LabelBinarizer
label_bin = LabelBinarizer()
y = label_bin.fit_transform(y)

# %% [markdown]
# # label array

# %%
y = np.array(y)

# %% [markdown]
# # train test split

# %%
from sklearn.model_selection import train_test_split
seed = 42
test_size = 0.30
X_train, X_test, y_train, y_test = train_test_split(X, y, random_state=seed, test_size=test_size)

# %% [markdown]
# # length of X_test

# %%
len(X_test)
# Out:
# 578

# %% [markdown]
# # Not necessary, only use to matching with my pc version

# %%
# !pip install tensorflow==2.3.1
# !pip install keras==2.4.3

# %% [markdown]
# # import some dependencies

# %%
from tensorflow.keras.layers import Input, Lambda, Dense, Flatten, Conv2D, MaxPooling2D, Dropout
from tensorflow.keras.models import Model
from tensorflow.keras.models import Sequential
from keras.preprocessing.image import ImageDataGenerator
import tensorflow as tf

# %% [markdown]
# # tensorflow version

# %%
tf.__version__
# Out:
# '2.3.0'

# %% [markdown]
# # keras version

# %%
import keras
keras.__version__
# Out:
# '2.4.3'

# %% [markdown]
# # Data Augmentation

# %%
train_generator = ImageDataGenerator(rescale=1/255, zoom_range=0.2, horizontal_flip=True, rotation_range=30)
test_generator = ImageDataGenerator(rescale=1/255)

train_generator = train_generator.flow(np.array(X_train), y_train, shuffle=False)
test_generator = test_generator.flow(np.array(X_test), y_test, shuffle=False)

# %% [markdown]
# # Model

# %%
model = Sequential()

model.add(Conv2D(256, (3, 3), activation="relu", input_shape=X_train.shape[1:]))
model.add(MaxPooling2D(2, 2))

model.add(Conv2D(128, (3, 3), activation="relu"))
model.add(MaxPooling2D(2, 2))

model.add(Conv2D(64, (3, 3), activation="relu"))
model.add(MaxPooling2D(2, 2))

model.add(Conv2D(32, (3, 3), activation="relu"))
model.add(MaxPooling2D(2, 2))

model.add(Flatten())
model.add(Dropout(0.5))

model.add(Dense(64, activation="relu"))
model.add(Dense(4, activation="softmax"))

model.compile(loss="categorical_crossentropy", metrics=["accuracy"], optimizer="adam")

model.summary()
# Out:
# Model: "sequential"
# _________________________________________________________________
# Layer (type)                 Output Shape              Param #
# =================================================================
# conv2d (Conv2D)              (None, 143, 143, 256)     7168
# _________________________________________________________________
# max_pooling2d (MaxPooling2D) (None, 71, 71, 256)       0
# _________________________________________________________________
# conv2d_1 (Conv2D)            (None, 69, 69, 128)       295040
# _________________________________________________________________
# max_pooling2d_1 (MaxPooling2 (None, 34, 34, 128)       0
# _________________________________________________________________
# conv2d_2 (Conv2D)            (None, 32, 32, 64)        73792
# _________________________________________________________________
# max_pooling2d_2 (MaxPooling2 (None, 16, 16, 64)        0
# _________________________________________________________________
# conv2d_3 (Conv2D)            (None, 14, 14, 32)        18464
# _________________________________________________________________
# max_pooling2d_3 (MaxPooling2 (None, 7, 7, 32)          0
# _________________________________________________________________
# flatten (Flatten)            (None, 1568)              0
# _________________________________________________________________
# dropout (Dropout)            (None, 1568)              0
# _________________________________________________________________
# dense (Dense)                (None, 64)                100416
# _________________________________________________________________
# dense_1 (Dense)              (None, 4)                 260
# =================================================================
# Total params: 495,140
# Trainable params: 495,140
# Non-trainable params: 0
# _________________________________________________________________

# %%
history = model.fit(train_generator, epochs=50, validation_data=test_generator, shuffle=True, validation_steps=len(test_generator))
# Out:
# Epoch 1/50
# 43/43 [==============================] - 7s 165ms/step - loss: 1.1165 - accuracy: 0.5160 - val_loss: 0.5563 - val_accuracy: 0.7543
# Epoch 2/50
# 43/43 [==============================] - 7s 155ms/step - loss: 0.6143 - accuracy: 0.7461 - val_loss: 0.4149 - val_accuracy: 0.8339
# Epoch 3/50
# 43/43 [==============================] - 7s 164ms/step - loss: 0.4119 - accuracy: 0.8285 - val_loss: 0.4082 - val_accuracy: 0.8149
# Epoch 4/50
# 43/43 [==============================] - 7s 164ms/step - loss: 0.4336 - accuracy: 0.8062 - val_loss: 0.3476 - val_accuracy: 0.8737
# Epoch 5/50
# 43/43 [==============================] - 7s 154ms/step - loss: 0.3416 - accuracy: 0.8552 - val_loss: 0.2945 - val_accuracy: 0.8910
# Epoch 6/50
# 43/43 [==============================] - 8s 175ms/step - loss: 0.3245 - accuracy: 0.8604 - val_loss: 0.3272 - val_accuracy: 0.8824
# Epoch 7/50
# 43/43 [==============================] - 7s 161ms/step - loss: 0.3025 - accuracy: 0.8812 - val_loss: 0.2662 - val_accuracy: 0.9083
# Epoch 8/50
# 43/43 [==============================] - 7s 153ms/step - loss: 0.2619 - accuracy: 0.8872 - val_loss: 0.2352 - val_accuracy: 0.9204
# Epoch 9/50
# 43/43 [==============================] - 7s 157ms/step - loss: 0.2619 - accuracy: 0.8938 - val_loss: 0.2370 - val_accuracy: 0.9221
# Epoch 10/50
# 43/43 [==============================] - 7s 153ms/step - loss: 0.2412 - accuracy: 0.8983 - val_loss: 0.2146 - val_accuracy: 0.9204
# Epoch 11/50
# 43/43 [==============================] - 7s 152ms/step - loss: 0.2245 - accuracy: 0.9131 - val_loss: 0.2046 - val_accuracy: 0.9239
# Epoch 12/50
# 43/43 [==============================] - 7s 157ms/step - loss: 0.2391 - accuracy: 0.9094 - val_loss: 0.3065 - val_accuracy: 0.8772
# Epoch 13/50
# 43/43 [==============================] - 7s 167ms/step - loss: 0.2463 - accuracy: 0.8909 - val_loss: 0.2117 - val_accuracy: 0.9187
# Epoch 14/50
# 43/43 [==============================] - 7s 160ms/step - loss: 0
50
# 43/43 [==============================] - 7s 161ms/step - loss: 0.1532 - accuracy: 0.9324 - val_loss: 0.1026 - val_accuracy: 0.9654
# Epoch 41/50
# 43/43 [==============================] - 7s 151ms/step - loss: 0.1183 - accuracy: 0.9510 - val_loss: 0.0929 - val_accuracy: 0.9671
# Epoch 42/50
# 43/43 [==============================] - 7s 170ms/step - loss: 0.1043 - accuracy: 0.9599 - val_loss: 0.1054 - val_accuracy: 0.9654
# Epoch 43/50
# 43/43 [==============================] - 7s 164ms/step - loss: 0.1184 - accuracy: 0.9473 - val_loss: 0.0972 - val_accuracy: 0.9654
# Epoch 44/50
# 43/43 [==============================] - 7s 153ms/step - loss: 0.1121 - accuracy: 0.9555 - val_loss: 0.0939 - val_accuracy: 0.9619
# Epoch 45/50
# 43/43 [==============================] - 7s 160ms/step - loss: 0.1007 - accuracy: 0.9547 - val_loss: 0.0933 - val_accuracy: 0.9689
# Epoch 46/50
# 43/43 [==============================] - 7s 156ms/step - loss: 0.1029 - accuracy: 0.9540 - val_loss: 0.0900 - val_accuracy: 0.9706
# Epoch 47/50
# 43/43 [==============================] - 6s 150ms/step - loss: 0.1133 - accuracy: 0.9547 - val_loss: 0.1039 - val_accuracy: 0.9654
# Epoch 48/50
# 43/43 [==============================] - 7s 173ms/step - loss: 0.1111 - accuracy: 0.9577 - val_loss: 0.0859 - val_accuracy: 0.9637
# Epoch 49/50
# 43/43 [==============================] - 7s 151ms/step - loss: 0.0828 - accuracy: 0.9681 - val_loss: 0.0856 - val_accuracy: 0.9706
# Epoch 50/50
# 43/43 [==============================] - 7s 161ms/step - loss: 0.1076 - accuracy: 0.9547 - val_loss: 0.0963 - val_accuracy: 0.9689

# %% [markdown]
# # history

# %%
accuracy = history.history['accuracy']
val_accuracy = history.history['val_accuracy']
loss = history.history['loss']
val_loss = history.history['val_loss']
epochs = range(len(accuracy))

plt.plot(epochs, accuracy, "b", label="trainning accuracy")
plt.plot(epochs, val_accuracy, "r", label="validation accuracy")
plt.legend()
plt.show()

plt.plot(epochs, loss, "b", label="trainning loss")
plt.plot(epochs, val_loss, "r", label="validation loss")
plt.legend()
plt.show()

# %% [markdown]
# # save model

# %%
model.save("drowiness_new6.h5")

# %%
model.save("drowiness_new6.model")

# %% [markdown]
# # Prediction

# %%
prediction = model.predict_classes(X_test)

# %%
prediction
# Out:
# array([3, 3, 2, 3, 1, 3, 3, 2, 1, 2, 3, 3, 3, 2, 2, 2, 3, 0, 0, 2, 3, 3,
#        2, 1, 0, 2, 2, 2, 3, 2, 3, 2, 3, 2, 0, 3, 3, 2, 1, 2, 3, 3, 2, 3,
#        2, 2, 3, 3, 2, 3, 3, 1, 2, 1, 2, 3, 2, 2, 2, 0, 3, 3, 1, 2, 2, 3,
#        2, 3, 2, 2, 1, 3, 3, 3, 2, 0, 0, 3, 1, 3, 2, 0, 3, 2, 2, 2, 2, 0,
#        3, 3, 2, 3, 3, 3, 1, 0, 3, 0, 3, 3, 3, 1, 3, 1, 2, 3, 2, 1, 2, 2,
#        1, 1, 2, 1, 0, 3, 3, 3, 2, 2, 3, 3, 3, 1, 1, 2, 3, 2, 2, 1, 3, 3,
#        0, 3, 1, 2, 2, 3, 3, 1, 2, 2, 2, 1, 3, 3, 3, 3, 2, 0, 3, 3, 3, 3,
#        2, 0, 1, 0, 3, 1, 3, 2, 2, 3, 2, 3, 3, 2, 3, 2, 3, 1, 2, 0, 3, 2,
#        2, 2, 0, 2, 3, 0, 2, 0, 3, 3, 3, 1, 2, 0, 1, 3, 2, 2, 3, 2, 3, 0,
#        3, 2, 3, 0, 2, 0, 0, 1, 2, 3, 2, 0, 3, 1, 2, 2, 2, 2, 1, 3, 1, 1,
#        1, 0, 3, 3, 3, 3, 3, 0, 1, 2, 0, 0, 3, 3, 1, 3, 3, 0, 3, 3, 1, 0,
#        0, 0, 3, 3, 3, 3, 3, 2, 3, 3, 2, 3, 2, 0, 2, 2, 2, 0, 3, 3, 2, 2,
#        3, 2, 2, 1, 2, 3, 2, 2, 2, 3, 3, 3, 3, 3, 0, 1, 0, 3, 3, 3, 3, 2,
#        2, 0, 2, 2, 3, 3, 2, 0, 2, 2, 1, 3, 2, 3, 1, 3, 3, 1, 3, 3, 0, 3,
#        3, 2, 2, 2, 1, 1, 0, 3, 3, 3, 3, 1, 2, 0, 3, 2, 2, 1, 3, 3, 3, 2,
#        2, 3, 2, 3, 3, 3, 3, 2, 1, 3, 2, 2, 2, 1, 2, 0, 3, 3, 2, 2, 2, 2,
#        2, 2, 3, 2, 0, 2, 1, 0, 2, 3, 2, 1, 3, 2, 3, 3, 3, 2, 2, 2, 2, 2,
#        2, 3, 1, 3, 3, 1, 3, 1, 3, 2, 2, 1, 0, 2, 2, 3, 2, 1, 2, 2, 2, 3,
#        3, 1, 0, 3, 0, 2, 3, 2, 2, 3, 1, 3, 3, 2, 3, 3, 1, 2, 3, 2, 2, 1,
#        1, 3, 2, 2, 3, 1, 3, 2, 2, 2, 2, 2, 0, 2, 0, 1, 2, 2, 1, 3, 2, 3,
#        3, 3, 2, 2, 3, 2, 1, 0, 3, 2, 2, 2, 2, 1, 2, 3, 3, 3, 1, 3, 2, 2,
#        2, 2, 3, 3, 0, 0, 1, 3, 3, 3, 2, 2, 2, 2, 2, 2, 1, 2, 1, 3, 3, 2,
#        2, 2, 2, 3, 2, 3, 3, 2, 3, 3, 3, 2, 3, 1, 0, 2, 2, 3, 2, 3, 0, 0,
#        1, 3, 0, 0, 3, 2, 2, 0, 2, 2, 3, 2, 3, 3, 3, 3, 2, 2, 0, 3, 2, 3,
#        2, 2, 3, 2, 2, 2, 3, 3, 2, 1, 2, 1, 3, 3, 1, 0, 3, 3, 3, 2, 2, 0,
#        3, 2, 2, 2, 2, 2, 3, 3, 2, 2, 1, 3, 2, 2, 3, 3, 2, 3, 2, 3, 3, 2,
#        3, 2, 2, 3, 2, 2])

# %% [markdown]
# # classification report

# %%
labels_new = ["yawn", "no_yawn", "Closed", "Open"]

# %%
from sklearn.metrics import classification_report
print(classification_report(np.argmax(y_test, axis=1), prediction, target_names=labels_new))
# Out:
#               precision    recall  f1-score   support
#
#         yawn       0.90      0.90      0.90        63
#      no_yawn       0.92      0.92      0.92        74
#       Closed       0.93      0.95      0.94       215
#         Open       0.95      0.93      0.94       226
#
#     accuracy                           0.93       578
#    macro avg       0.93      0.93      0.93       578
# weighted avg       0.93      0.93      0.93       578

# %% [markdown]
# # predicting function

# %%
labels_new = ["yawn", "no_yawn", "Closed", "Open"]
IMG_SIZE = 145
def prepare(filepath, face_cas="../input/prediction-images/haarcascade_frontalface_default.xml"):
    img_array = cv2.imread(filepath, cv2.IMREAD_COLOR)
    img_array = img_array / 255
    resized_array = cv2.resize(img_array, (IMG_SIZE, IMG_SIZE))
    return resized_array.reshape(-1, IMG_SIZE, IMG_SIZE, 3)

model = tf.keras.models.load_model("./drowiness_new6.h5")

# %% [markdown]
# # Prediction
# ## 0-yawn, 1-no_yawn, 2-Closed, 3-Open

# %%
# prepare("../input/drowsiness-dataset/train/no_yawn/1068.jpg")
prediction = model.predict([prepare("../input/drowsiness-dataset/train/no_yawn/1067.jpg")])
np.argmax(prediction)

# %%
prediction = model.predict([prepare("../input/drowsiness-dataset/train/Closed/_101.jpg")])
np.argmax(prediction)
# Out:
# 2

# %%
prediction = model.predict([prepare("../input/drowsiness-dataset/train/Open/_104.jpg")])
np.argmax(prediction)
# Out:
# 3

# %%
prediction = model.predict([prepare("../input/drowsiness-dataset/train/yawn/113.jpg")])
np.argmax(prediction)
# Out:
# 3
