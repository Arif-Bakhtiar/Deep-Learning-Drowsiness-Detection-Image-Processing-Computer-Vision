# %%
import tensorflow as tf
from tensorflow.keras.preprocessing.image import ImageDataGenerator , load_img, img_to_array, array_to_img
from keras.datasets import mnist
import os
from sklearn.model_selection import train_test_split
from sklearn.preprocessing import LabelBinarizer
import matplotlib.pyplot as plt
import numpy as np
import seaborn as sns
from sklearn.metrics import confusion_matrix, auc, roc_curve
from tensorflow.keras.applications import InceptionResNetV2  # Use Inception-ResNetV2
from tensorflow.keras.models import Sequential
from tensorflow.keras.layers import Dense, GlobalAveragePooling2D, Dropout
# Out:
# /opt/conda/lib/python3.10/site-packages/scipy/__init__.py:146: UserWarning: A NumPy version >=1.16.5 and <1.23.0 is required for this version of SciPy (detected version 1.23.5
#   warnings.warn(f"A NumPy version >={np_minversion} and <{np_maxversion}"

# %%
# Check GPU availability
print(tf.test.is_gpu_available())
print(tf.config.list_physical_devices('GPU'))
# Out:
# True
# [PhysicalDevice(name='/physical_device:GPU:0', device_type='GPU')]

# %%
# Load the dataset and visualize images
labels = os.listdir("/kaggle/input/augmented-dataset-drowsiness-detection/train")

# %%
# Load the data using ImageDataGenerator
datagen = ImageDataGenerator(
    rescale=1./255,
    validation_split=0.2,
    zoom_range=0.2,
    horizontal_flip=True,
    rotation_range=30
)

# %%
# Load the dataset and split into training and testing sets
directory = "/kaggle/input/augmented-dataset-drowsiness-detection/train"
target_size = (80, 80)
batch_size = 11600 # Adjust batch size as needed

# Load the dataset and split into training and testing sets
data = datagen.flow_from_directory(
    directory,
    target_size=target_size,
    batch_size=batch_size,  # Specify batch size here
    class_mode='categorical',
    subset='training'
)

# Split the data into training and testing sets
x, y = data.next()
x_train, x_test, y_train, y_test = train_test_split(x, y, test_size=0.2, random_state=42)

# Encode the labels using one-hot encoding
label_bin = LabelBinarizer()
y_train = label_bin.fit_transform(y_train)
y_test = label_bin.transform(y_test)
# Out:
# Found 11600 images belonging to 4 classes.

# %%
# Create the Inception-ResNetV2 base model
base_model = InceptionResNetV2(weights='imagenet', include_top=False, input_shape=(80, 80, 3))
# Out:
# Downloading data from https://storage.googleapis.com/tensorflow/keras-applications/inception_resnet_v2/inception_resnet_v2_weights_tf_dim_ordering_tf_kernels_notop.h5
# 219055592/219055592 [==============================] - 1s 0us/step

# %%
# Add custom layers for classification on top of the base model
model = Sequential([
    base_model,
    GlobalAveragePooling2D(),
    Dense(64, activation='relu'),
    Dropout(0.5),
    Dense(4, activation='sigmoid')
])

# %%
# Freeze the layers in the base model
for layer in base_model.layers:
    layer.trainable = False

# %%
# Compile the model
optimizer = tf.keras.optimizers.Adam(learning_rate=0.001)
model.compile(loss="categorical_crossentropy", metrics=["accuracy"], optimizer=optimizer)
model.summary()
# Out:
# Model: "sequential"
# _________________________________________________________________
#  Layer (type)                Output Shape              Param #
# =================================================================
#  inception_resnet_v2 (Functi  (None, 1, 1, 1536)       54336736
#  onal)
#
#  global_average_pooling2d (G  (None, 1536)             0
#  lobalAveragePooling2D)
#
#  dense (Dense)               (None, 64)                98368
#
#  dropout (Dropout)           (None, 64)                0
#
#  dense_1 (Dense)             (None, 4)                 260
#
# =================================================================
# Total params: 54,435,364
# Trainable params: 98,628
# Non-trainable params: 54,336,736
# _________________________________________________________________

# %%
# Train the model
hist = model.fit(x_train, y_train, epochs=100, validation_data=(x_test, y_test), batch_size=45)  # Specify batch size here
# Out:
# Epoch 1/100
# 207/207 [==============================] - 33s 74ms/step - loss: 0.5734 - accuracy: 0.7223 - val_loss: 0.3805 - val_accuracy: 0.8030
# Epoch 2/100
# 207/207 [==============================] - 11s 52ms/step - loss: 0.4076 - accuracy: 0.7817 - val_loss: 0.3556 - val_accuracy: 0.8198
# Epoch 3/100
# 207/207 [==============================] - 10s 47ms/step - loss: 0.3871 - accuracy: 0.7922 - val_loss: 0.3347 - val_accuracy: 0.8216
# Epoch 4/100
# 207/207 [==============================] - 11s 51ms/step - loss: 0.3629 - accuracy: 0.8022 - val_loss: 0.3278 - val_accuracy: 0.8147
# Epoch 5/100
# 207/207 [==============================] - 10s 48ms/step - loss: 0.3521 - accuracy: 0.8057 - val_loss: 0.3248 - val_accuracy: 0.8216
# Epoch 6/100
# 207/207 [==============================] - 10s 51ms/step - loss: 0.3431 - accuracy: 0.8116 - val_loss: 0.3400 - val_accuracy: 0.8095
# Epoch 7/100
# 207/207 [==============================] - 10s 47ms/step - loss: 0.3353 - accuracy: 0.8206 - val_loss: 0.3226 - val_accuracy: 0.8155
# Epoch 8/100
# 207/207 [==============================] - 10s 48ms/step - loss: 0.3384 - accuracy: 0.8205 - val_loss: 0.3170 - val_accuracy: 0.8207
# Epoch 9/100
# 207/207 [==============================] - 10s 51ms/step - loss: 0.3249 - accuracy: 0.8236 - val_loss: 0.3440 - val_accuracy: 0.8116
# Epoch 10/100
# 207/207 [==============================] - 10s 47ms/step - loss: 0.3171 - accuracy: 0.8335 - val_loss: 0.3150 - val_accuracy: 0.8233
# Epoch 11/100
# 207/207 [==============================] - 10s 47ms/step - loss: 0.3149 - accuracy: 0.8327 - val_loss: 0.3103 - val_accuracy: 0.8306
# Epoch 12/100
# 207/207 [==============================] - 10s 47ms/step - loss: 0.3033 - accuracy: 0.8307 - val_loss: 0.3156 - val_accuracy: 0.8284
# Epoch 13/100
# 207/207 [==============================] - 11s 51ms/step - loss: 0.3025 - accuracy: 0.8409 - val_loss: 0.3156 - val_accuracy: 0.8345
# Epoch 14/100
# 207/207 [==============================] - 11s 51ms/step - loss: 0.2973 - accuracy: 0.8454 - val_loss: 0.3229 - val_accuracy: 0.8198
# Epoch 15/100
# 207/207 [==============================] - 10s 47ms/step - loss: 0.2876 - accuracy: 0.8486 - val_loss: 0.3270 - val_accuracy: 0.8250
# Epoch 16/100
# 207/207 [==============================] - 10s 47ms/step - loss: 0.2909 - accuracy: 0.8411 - val_loss: 0.3201 - val_accuracy: 0.8293
# Epoch 17/100
# 207/207 [==============================] - 10s 50ms/step - loss: 0.2846 - accuracy: 0.8443 - val_loss: 0.3193 - val_accuracy: 0.8211
# Epoch 18/100
# 207/207 [==============================] - 10s 47ms/step - loss: 0.2885 - accuracy: 0.8476 - val_loss: 0.3119 - val_accuracy: 0.8353
# Epoch 19/100
# 207/207 [==============================] - 11s 51ms/step - loss: 0.2783 - accuracy: 0.8511 - val_loss: 0.3253 - val_accuracy: 0.8233
# Epoch 20/100
# 207/207 [==============================] - 10s 51ms/step - loss: 0.2826 - accuracy: 0.8500 - val_loss: 0.3236 - val_accuracy: 0.8241
# Epoch 21/100
# 207/207 [==============================] - 11s 51ms/step - loss: 0.2823 - accuracy: 0.8522 - val_loss: 0.3266 - val_accuracy: 0.8276
# Epoch 22/100
# 207/207 [==============================] - 10s 47ms/step - loss: 0.2763 - accuracy: 0.8524 - val_loss: 0.3225 - val_accuracy: 0.8293
# Epoch 23/100
# 207/207 [==============================] - 10s 46ms/step - loss: 0.2681 - accuracy: 0.8609 - val_loss: 0.3212 - val_accuracy: 0.8267
# Epoch 24/100
# 207/207 [==============================] - 10s 48ms/step - loss: 0.2693 - accuracy: 0.8565 - val_loss: 0.3244 - val_accuracy: 0.8289
# Epoch 25/100
# 207/207 [==============================] - 10s 47ms/step - loss: 0.2578 - accuracy: 0.8656 - val_loss: 0.3301 - val_accuracy: 0.8280
# Epoch 26/100
# 207/207 [==============================] - 10s 51ms/step - loss: 0.2529 - accuracy: 0.8656 - val_loss: 0.3311 - val_accuracy: 0.8315
# Epoch 27/100
# 207/207 [==============================] - 10s 48ms/step - loss: 0.2546 - accuracy: 0.8663 - val_loss: 0.3246 - val_accuracy: 0.8289
# Epoch 28/100
# 207/207 [==============================] - 10s 46ms/step - loss: 0.2514 - accuracy: 0.8708 - val_loss: 0.3431 - val_accuracy: 0.8241
# Epoch 29/100
# 207/207 [==============================] - 10s 47ms/step - loss: 0.2406 - accuracy: 0.8713 - val_loss: 0.3468 - val_accuracy: 0.8190
# Epoch 30/100
# 207/207 [==============================] - 11s 52ms/step - loss: 0.2540 - accuracy: 0.8704 - val_loss: 0.3368 - val_accuracy: 0.8310
# Epoch 31/100
# 207/207 [==============================] - 11s 51ms/step - loss: 0.2630 - accuracy: 0.8650 - val_loss: 0.3557 - val_accuracy: 0.8284
# Epoch 32/100
# 207/207 [==============================] - 10s 47ms/step - loss: 0.2563 - accuracy: 0.8682 - val_loss: 0.3488 - val_accuracy: 0.8302
# Epoch 33/100
# 207/207 [==============================] - 10s 48ms/step - loss: 0.2442 - accuracy: 0.8721 - val_loss: 0.3501 - val_accuracy: 0.8194
# Epoch 34/100
# 207/207 [==============================] - 10s 47ms/step - loss: 0.2408 - accuracy: 0.8745 - val_loss: 0.3470 - val_accuracy: 0.8190
# Epoch 35/100
# 207/207 [==============================] - 11s 51ms/step - loss: 0.2363 - accuracy: 0.8769 - val_loss: 0.3414 - val_accuracy: 0.8328
# Epoch 36/100
# 207/207 [==============================] - 10s 48ms/step - loss: 0.2375 - accuracy: 0.8755 - val_loss: 0.3392 - val_accuracy: 0.8289
# Epoch 37/100
# 207/207 [==============================] - 11s 51ms/step - loss: 0.2354 - accuracy: 0.8801 - val_loss: 0.3501 - val_accuracy: 0.8259
# Epoch 38/100
# 207/207 [==============================] - 10s 51ms/step - loss: 0.2384 - accuracy: 0.8767 - val_loss: 0.3510 - val_accuracy: 0.8310
# Epoch 39/100
# 207/207 [==============================] - 10s 48ms/step - loss: 0.2300 - accuracy: 0.8770 - val_loss: 0.3343 - val_accuracy: 0.8263
# Epoch 40/100
# 207/207 [==============================] - 10s 50ms/step - loss: 0.2235 - accuracy: 0.8818 - val_loss: 0.3441 - val_accuracy: 0.8259
# Epoch 41/100
# 207/207 [==============================] - 10s 46ms/step - loss: 0.2226 - accuracy: 0.8848 - val_loss: 0.3616 - val_accuracy: 0.8328
# Epoch 42/100
# 207/207 [==============================] - 10s 51ms/step - loss: 0.2150 - accuracy: 0.8918 - val_loss: 0.3694 - val_accuracy: 0.8336
# Epoch 43/100
# 207/207 [==============================] - 10s 50ms/step - loss: 0.2164 - accuracy: 0.8879 - val_loss: 0.3648 - val_accuracy: 0.8323
# Epoch 44/100
# 207/207 [==============================] - 10s 50ms/step - loss: 0.2140 - accuracy: 0.8865 - val_loss: 0.3733 - val_accuracy: 0.8293
# Epoch 45/100
# 207/207 [==============================] - 10s 47ms/step - loss: 0.2150 - accuracy: 0.8931 - val_loss: 0.3958 - val_accuracy: 0.8272
# Epoch 46/100
# 207/207 [==============================] - 10s 47ms/step - loss: 0.2124 - accuracy: 0.8894 - val_loss: 0.3838 - val_accuracy: 0.8345
# Epoch 47/100
# 207/207 [==============================] - 10s 46ms/step - loss: 0.2152 - accuracy: 0.8903 - val_loss: 0.3485 - val_accuracy: 0.8323
# Epoch 48/100
# 207/207 [==============================] - 10s 50ms/step - loss: 0.2018 - accuracy: 0.8966 - val_loss: 0.3745 - val_accuracy: 0.8293
# Epoch 49/100
# 207/207 [==============================] - 10s 48ms/step - loss: 0.2082 - accuracy: 0.8885 - val_loss: 0.3783 - val_accuracy: 0.8345
# Epoch 50/100
# 207/207 [==============================] - 10s 50ms/step - loss: 0.2112 - accuracy: 0.8923 - val_loss: 0.3727 - val_accuracy: 0.8250
# Epoch 51/100
# 207/207 [==============================] - 10s 46ms/step - loss: 0.2002 - accuracy: 0.8977 - val_loss: 0.3996 - val_accuracy: 0.8297
# Epoch 52/100
# 207/207 [==============================] - 11s 52ms/step - loss: 0
100
# 207/207 [==============================] - 10s 46ms/step - loss: 0.1551 - accuracy: 0.9235 - val_loss: 0.4443 - val_accuracy: 0.8297
# Epoch 85/100
# 207/207 [==============================] - 10s 50ms/step - loss: 0.1688 - accuracy: 0.9156 - val_loss: 0.4218 - val_accuracy: 0.8319
# Epoch 86/100
# 207/207 [==============================] - 10s 48ms/step - loss: 0.1536 - accuracy: 0.9227 - val_loss: 0.4772 - val_accuracy: 0.8276
# Epoch 87/100
# 207/207 [==============================] - 10s 47ms/step - loss: 0.1648 - accuracy: 0.9169 - val_loss: 0.4715 - val_accuracy: 0.8293
# Epoch 88/100
# 207/207 [==============================] - 10s 47ms/step - loss: 0.1640 - accuracy: 0.9163 - val_loss: 0.4551 - val_accuracy: 0.8336
# Epoch 89/100
# 207/207 [==============================] - 10s 47ms/step - loss: 0.1561 - accuracy: 0.9227 - val_loss: 0.5024 - val_accuracy: 0.8397
# Epoch 90/100
# 207/207 [==============================] - 10s 51ms/step - loss: 0.1591 - accuracy: 0.9190 - val_loss: 0.5447 - val_accuracy: 0.8379
# Epoch 91/100
# 207/207 [==============================] - 10s 46ms/step - loss: 0.1622 - accuracy: 0.9207 - val_loss: 0.5461 - val_accuracy: 0.8397
# Epoch 92/100
# 207/207 [==============================] - 10s 47ms/step - loss: 0.1583 - accuracy: 0.9187 - val_loss: 0.5010 - val_accuracy: 0.8315
# Epoch 93/100
# 207/207 [==============================] - 10s 48ms/step - loss: 0.1547 - accuracy: 0.9248 - val_loss: 0.5362 - val_accuracy: 0.8293
# Epoch 94/100
# 207/207 [==============================] - 10s 50ms/step - loss: 0.1590 - accuracy: 0.9227 - val_loss: 0.5054 - val_accuracy: 0.8384
# Epoch 95/100
# 207/207 [==============================] - 10s 46ms/step - loss: 0.1601 - accuracy: 0.9180 - val_loss: 0.4569 - val_accuracy: 0.8302
# Epoch 96/100
# 207/207 [==============================] - 10s 48ms/step - loss: 0.1695 - accuracy: 0.9187 - val_loss: 0.5450 - val_accuracy: 0.8306
# Epoch 97/100
# 207/207 [==============================] - 10s 51ms/step - loss: 0.1532 - accuracy: 0.9225 - val_loss: 0.6429 - val_accuracy: 0.8246
# Epoch 98/100
# 207/207 [==============================] - 11s 51ms/step - loss: 0.1496 - accuracy: 0.9267 - val_loss: 0.4935 - val_accuracy: 0.8302
# Epoch 99/100
# 207/207 [==============================] - 11s 52ms/step - loss: 0.1537 - accuracy: 0.9244 - val_loss: 0.5289 - val_accuracy: 0.8353
# Epoch 100/100
# 207/207 [==============================] - 11s 51ms/step - loss: 0.1558 - accuracy: 0.9245 - val_loss: 0.5200 - val_accuracy: 0.8323

# %%
# Save the model
model.save("drowsiness_inceptionv4.h5")
model.save("drowsiness_inceptionv4.model")

# %%
# Plot accuracy and loss
accuracy = hist.history['accuracy']
val_accuracy = hist.history['val_accuracy']
loss = hist.history['loss']
val_loss = hist.history['val_loss']
epochs = range(len(accuracy))

plt.plot(epochs, accuracy, "b", label="training accuracy")
plt.plot(epochs, val_accuracy, "r", label="validation accuracy")
plt.xlabel('Epochs')
plt.ylabel('Accuracy')
plt.title('Training & Validation Accuracy')
plt.legend()
plt.show()

# %%
plt.plot(epochs, loss, "b", label="training loss")
plt.plot(epochs, val_loss, "r", label="validation loss")
plt.xlabel('Epochs')
plt.ylabel('Loss')
plt.title('Training & Validation Loss')
plt.legend()
plt.show()

# %%
# Make predictions and evaluate the model
y_true = np.argmax(y_test, axis=1)
y_pred = model.predict(x_test)
y_pred_classes = np.argmax(y_pred, axis=1)
# Out:
# 73/73 [==============================] - 7s 36ms/step

# %%
# Confusion Matrix
confusion_mtx = confusion_matrix(y_true, y_pred_classes)

# Plot Confusion Matrix
plt.figure(figsize=(8, 6))
sns.heatmap(confusion_mtx, annot=True, fmt='d', cmap='Blues')
plt.xlabel('Predicted')
plt.ylabel('True')
plt.show()

# %%
# Print the confusion matrix
print("Confusion Matrix:\n", confusion_mtx)
# Out:
# Confusion Matrix:
#  [[564   7   1   1]
#  [ 16 568   0   1]
#  [  0   0 434 124]
#  [  0   0 239 365]]

# %%
# Accuracy Score
accuracy = np.sum(y_true == y_pred_classes) / len(y_true)
print("Accuracy:", accuracy)
# Out:
# Accuracy: 0.8323275862068965

# %%
# Classification Report
from sklearn.metrics import classification_report
class_report = classification_report(y_true, y_pred_classes, target_names=labels)
print("Classification Report:\n", class_report)
# Out:
# Classification Report:
#                precision    recall  f1-score   support
#
#       Closed       0.97      0.98      0.98       573
#         Open       0.99      0.97      0.98       585
#         yawn       0.64      0.78      0.70       558
#      no_yawn       0.74      0.60      0.67       604
#
#     accuracy                           0.83      2320
#    macro avg       0.84      0.83      0.83      2320
# weighted avg       0.84      0.83      0.83      2320

# %%
# Compute ROC curves and AUC for each class
n_classes = 4
fpr = dict()
tpr = dict()

roc_auc = dict()

for i in range(n_classes):
    fpr[i], tpr[i], _ = roc_curve(y_test[:, i], y_pred[:, i])
    roc_auc[i] = auc(fpr[i], tpr[i])

# Plot the ROC curves for each class
plt.figure(figsize=(8, 6))
for i in range(n_classes):
    plt.plot(fpr[i], tpr[i], lw=2, label='Class {} (AUC = {:.2f})'.format(i, roc_auc[i]))

plt.plot([0, 1], [0, 1], color='navy', lw=2, linestyle='--')
plt.xlim([0.0, 1.0])
plt.ylim([0.0, 1.05])
plt.xlabel('False Positive Rate')
plt.ylabel('True Positive Rate')
plt.title('Receiver Operating Characteristic (ROC) Curve')
plt.legend(loc='lower right')
plt.show()
