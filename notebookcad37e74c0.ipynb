# %%
import tensorflow as tf
from tensorflow.keras.preprocessing.image import ImageDataGenerator
import os
from sklearn.model_selection import train_test_split
from sklearn.preprocessing import LabelBinarizer
import matplotlib.pyplot as plt
import numpy as np
import seaborn as sns
from sklearn.metrics import confusion_matrix, auc, roc_curve
from tensorflow.keras.applications import InceptionV3
from tensorflow.keras.models import Sequential
from tensorflow.keras.layers import Dense, GlobalAveragePooling2D, Dropout

# Check GPU availability
print(tf.test.is_gpu_available())
print(tf.config.list_physical_devices('GPU'))

# Load the dataset and visualize images
labels = os.listdir("/kaggle/input/drowsiness-dataset/train")

# Load the data using ImageDataGenerator
datagen = ImageDataGenerator(
    rescale=1./255,
    validation_split=0.2,
    zoom_range=0.2,
    horizontal_flip=True,
    rotation_range=30
)

# Load the dataset and split into training and testing sets
directory = "../input/drowsiness-dataset/train"
target_size = (240, 240)
batch_size = 4000  # Adjust batch size as needed

# Load the dataset and split into training and testing sets
data = datagen.flow_from_directory(
    directory,
    target_size=target_size,
    batch_size=batch_size,  # Specify batch size here
    class_mode='categorical',
    subset='training'
)

# Split the data into training and testing sets
x, y = data.next()
x_train, x_test, y_train, y_test = train_test_split(x, y, test_size=0.3, random_state=42)

# Encode the labels using one-hot encoding
label_bin = LabelBinarizer()
y_train = label_bin.fit_transform(y_train)
y_test = label_bin.transform(y_test)

# Create the InceptionV3 base model
base_model = InceptionV3(weights='imagenet', include_top=False, input_shape=(240, 240, 3))

# Add custom layers for classification on top of the base model
model = Sequential([
    base_model,
    GlobalAveragePooling2D(),
    Dense(128, activation='relu'),
    Dropout(0.5),
    Dense(4, activation='softmax')
])

# Freeze the layers in the base model
for layer in base_model.layers:
    layer.trainable = False

# Compile the model
optimizer = tf.keras.optimizers.Adam(learning_rate=0.001)
model.compile(loss="categorical_crossentropy", metrics=["accuracy"], optimizer=optimizer)
model.summary()

# Train the model
hist = model.fit(x_train, y_train, epochs=50, validation_data=(x_test, y_test), batch_size=40)  # Specify batch size here

# Save the model
model.save("drowsiness_inceptionv3.h5")
model.save("drowsiness_inceptionv3.model")

# Plot accuracy and loss
accuracy = hist.history['accuracy']
val_accuracy = hist.history['val_accuracy']
loss = hist.history['loss']
val_loss = hist.history['val_loss']
epochs = range(len(accuracy))

plt.plot(epochs, accuracy, "b", label="training accuracy")
plt.plot(epochs, val_accuracy, "r", label="validation accuracy")
plt.legend()
plt.show
plt.plot(epochs, loss, "b", label="training loss")
plt.plot(epochs, val_loss, "r", label="validation loss")
plt.legend()
plt.show()

# Make predictions and evaluate the model
y_true = np.argmax(y_test, axis=1)
y_pred = model.predict(x_test)
y_pred_classes = np.argmax(y_pred, axis=1)

# Confusion Matrix
confusion_mtx = confusion_matrix(y_true, y_pred_classes)

# Plot Confusion Matrix
plt.figure(figsize=(8, 6))
sns.heatmap(confusion_mtx, annot=True, fmt='d', cmap='Blues')
plt.xlabel('Predicted')
plt.ylabel('True')
plt.show()

# Print the confusion matrix
print("Confusion Matrix:\n", confusion_mtx)

# Accuracy Score
accuracy = np.sum(y_true == y_pred_classes) / len(y_true)
print("Accuracy:", accuracy)

# Compute ROC curves and AUC for each class
n_classes = 4
fpr = dict()
tpr = dict()
roc_auc = dict()

for i in range(n_classes):
    fpr[i], tpr[i], _ = roc_curve(y_test[:, i], y_pred[:, i])
    roc_auc[i] = auc(fpr[i], tpr[i])

# Plot the ROC curves for each class
plt.figure(figsize=(8, 6))
for i in range(n_classes):
    plt.plot(fpr[i], tpr[i], lw=2, label='Class {} (AUC = {:.2f})'.format(i, roc_auc[i]))

plt.plot([0, 1], [0, 1], color='navy', lw=2, linestyle='--')
plt.xlim([0.0, 1.0])
plt.ylim([0.0, 1.05])
plt.xlabel('False Positive Rate')
plt.ylabel('True Positive Rate')
plt.title('Receiver Operating Characteristic (ROC) Curve')
plt.legend(loc='lower right')
plt.show()
# Out:
# True
# [PhysicalDevice(name='/physical_device:GPU:0', device_type='GPU')]
# Found 2321 images belonging to 4 classes.
# Model: "sequential_1"
# _________________________________________________________________
#  Layer (type)                Output Shape              Param #
# =================================================================
#  inception_v3 (Functional)   (None, 6, 6, 2048)        21802784
#
#  global_average_pooling2d_1   (None, 2048)             0
#  (GlobalAveragePooling2D)
#
#  dense_2 (Dense)             (None, 128)               262272
#
#  dropout_1 (Dropout)         (None, 128)               0
#
#  dense_3 (Dense)             (None, 4)                 516
#
# =================================================================
# Total params: 22,065,572
# Trainable params: 262,788
# Non-trainable params: 21,802,784
# _________________________________________________________________
# Epoch 1/50
# 41/41 [==============================] - 11s 157ms/step - loss: 0.6467 - accuracy: 0.6933 - val_loss: 0.3319 - val_accuracy: 0.8250
# Epoch 2/50
# 41/41 [==============================] - 4s 102ms/step - loss: 0.3679 - accuracy: 0.8097 - val_loss: 0.2877 - val_accuracy: 0.8666
# Epoch 3/50
# 41/41 [==============================] - 4s 102ms/step - loss: 0.3275 - accuracy: 0.8405 - val_loss: 0.2670 - val_accuracy: 0.8723
# Epoch 4/50
# 41/41 [==============================] - 4s 99ms/step - loss: 0.3087 - accuracy: 0.8541 - val_loss: 0.3254 - val_accuracy: 0.8020
# Epoch 5/50
# 41/41 [==============================] - 4s 101ms/step - loss: 0.2758 - accuracy: 0.8633 - val_loss: 0.2372 - val_accuracy: 0.8938
# Epoch 6/50
# 41/41 [==============================] - 4s 106ms/step - loss: 0.2408 - accuracy: 0.8873 - val_loss: 0.2246 - val_accuracy: 0.9039
# Epoch 7/50
# 41/41 [==============================] - 4s 102ms/step - loss: 0.2330 - accuracy: 0.8916 - val_loss: 0.2261 - val_accuracy: 0.8924
# Epoch 8/50
# 41/41 [==============================] - 4s 99ms/step - loss: 0.2301 - accuracy: 0.8953 - val_loss: 0.2083 - val_accuracy: 0.9082
# Epoch 9/50
# 41/41 [==============================] - 4s 101ms/step - loss: 0.2029 - accuracy: 0.9089 - val_loss: 0.2052 - val_accuracy: 0.9139
# Epoch 10/50
# 41/41 [==============================] - 4s 102ms/step - loss: 0.1923 - accuracy: 0.9107 - val_loss: 0.2091 - val_accuracy: 0.9110
# Epoch 11/50
# 41/41 [==============================] - 4s 102ms/step - loss: 0.1786 - accuracy: 0.9267 - val_loss: 0.2035 - val_accuracy: 0.9039
# Epoch 12/50
# 41/41 [==============================] - 4s 101ms/step - loss: 0.1790 - accuracy: 0.9218 - val_loss: 0.2725 - val_accuracy: 0.8709
# Epoch 13/50
# 41/41 [==============================] - 4s 101ms/step - loss: 0.1775 - accuracy: 0.9273 - val_loss: 0.1999 - val_accuracy: 0.9053
# Epoch 14/50
# 41/41 [==============================] - 4s 104ms/step - loss: 0.1603 - accuracy: 0.9353 - val_loss: 0.2213 - val_accuracy: 0.8996
# Epoch 15/50
# 41/41 [==============================] - 4s 99ms/step - loss: 0.1585 - accuracy: 0.9329 - val_loss: 0.1962 - val_accuracy: 0.9154
# Epoch 16/50
# 41/41 [==============================] - 4s 99ms/step - loss: 0.1361 - accuracy: 0.9421 - val_loss: 0.1874 - val_accuracy: 0.9154
# Epoch 17/50
# 41/41 [==============================] - 4s 99ms/step - loss: 0.1430 - accuracy: 0.9427 - val_loss: 0.1812 - val_accuracy: 0.9154
# Epoch 18/50
# 41/41 [==============================] - 4s 100ms/step - loss: 0.1340 - accuracy: 0.9433 - val_loss: 0.2044 - val_accuracy: 0.9125
# Epoch 19/50
# 41/41 [==============================] - 4s 99ms/step - loss: 0.1361 - accuracy: 0.9464 - val_loss: 0.1988 - val_accuracy: 0.9197
# Epoch 20/50
# 41/41 [==============================] - 4s 101ms/step - loss: 0.1423 - accuracy: 0.9372 - val_loss: 0.2605 - val_accuracy: 0.8967
# Epoch 21/50
# 41/41 [==============================] - 4s 101ms/step - loss: 0.1346 - accuracy: 0.9464 - val_loss: 0.2038 - val_accuracy: 0.9139
# Epoch 22/50
# 41/41 [==============================] - 4s 101ms/step - loss: 0.1218 - accuracy: 0.9464 - val_loss: 0.2076 - val_accuracy: 0.9096
# Epoch 23/50
# 41/41 [==============================] - 4s 99ms/step - loss: 0.1380 - accuracy: 0.9433 - val_loss: 0.1848 - val_accuracy: 0.9197
# Epoch 24/50
# 41/41 [==============================] - 4s 98ms/step - loss: 0.1273 - accuracy: 0.9501 - val_loss: 0.1946 - val_accuracy: 0.9297
# Epoch 25/50
# 41/41 [==============================] - 4s 103ms/step - loss: 0.1228 - accuracy: 0.9538 - val_loss: 0.1810 - val_accuracy: 0.9168
# Epoch 26/50
# 41/41 [==============================] - 4s 102ms/step - loss: 0.0943 - accuracy: 0.9649 - val_loss: 0.1945 - val_accuracy: 0.9311
# Epoch 27/50
# 41/41 [==============================] - 4s 102ms/step - loss: 0.0945 - accuracy: 0.9618 - val_loss: 0.1931 - val_accuracy: 0.9211
# Epoch 28/50
# 41/41 [==============================] - 4s 102ms/step - loss: 0.1094 - accuracy: 0.9550 - val_loss: 0.2133 - val_accuracy: 0.9168
# Epoch 29/50
# 41/41 [==============================] - 4s 105ms/step - loss: 0.0963 - accuracy: 0.9612 - val_loss: 0.1924 - val_accuracy: 0.9326
# Epoch 30/50
# 41/41 [==============================] - 4s 99ms/step - loss: 0.0781 - accuracy: 0.9704 - val_loss: 0.1936 - val_accuracy: 0.9254
# Epoch 31/50
# 41/41 [==============================] - 4s 102ms/step - loss: 0.0805 - accuracy: 0.9729 - val_loss: 0.1924 - val_accuracy: 0.9254
# Epoch 32/50
# 41/41 [==============================] - 4s 98ms/step - loss: 0.0776 - accuracy: 0.9674 - val_loss: 0.1826 - val_accuracy: 0.9354
# Epoch 33/50
# 41/41 [==============================] - 4s 98ms/step - loss: 0.0926 - accuracy: 0.9587 - val_loss: 0.2036 - val_accuracy: 0.9240
# Epoch 34/50
# 41/41 [==============================] - 4s 101ms/step - loss: 0.1050 - accuracy: 0.9575 - val_loss: 0.1989 - val_accuracy: 0.9240
# Epoch 35/50
# 41/41 [==============================] - 4s 98ms/step - loss: 0.0881 - accuracy: 0.9655 - val_loss: 0.1766 - val_accuracy: 0.9240
# Epoch 36/50
# 41/41 [==============================] - 4s 101ms/step - loss: 0.0930 - accuracy: 0.9612 - val_loss: 0.1790 - val_accuracy: 0.9240
# Epoch 37/50
# 41/41 [==============================] - 4s 102ms/step - loss: 0.0939 - accuracy: 0.9643 - val_loss: 0.2463 - val_accuracy: 0.9168
# Epoch 38/50
# 41/41 [==============================] - 4s 102ms/step - loss: 0.0890 - accuracy: 0.9667 - val_loss: 0.2325 - val_accuracy: 0.9268
# Epoch 39/50
# 41/41 [==============================] - 4s 102ms/step - loss: 0.0686 - accuracy: 0.9772 - val_loss: 0.2064 - val_accuracy: 0.9168
# Epoch 40/50
# 41/41 [==============================] - 4s 99ms/step - loss: 0.0747 - accuracy: 0.9748 - val_loss: 0.2066 - val_accuracy: 0.9197
# Epoch 41/50
# 41/41 [==============================] - 4s 102ms/step - loss: 0.0770 - accuracy: 0.9680 - val_loss: 0.2204 - val_accuracy: 0.9326
# Epoch 42/50
# 41/41 [==============================] - 4s 101ms/step - loss: 0.0849 - accuracy: 0.9667 - val_loss: 0.1869 - val_accuracy: 0.9283
# Epoch 43/50
# 41/41 [==============================] - 4s 98ms/step - loss: 0.0708 - accuracy: 0.9692 - val_loss: 0.1943 - val_accuracy: 0.9311
# Epoch 44/50
# 41/41 [==============================] - 4s 103ms/step - loss: 0.0779 - accuracy: 0.9711 - val_loss: 0.1944 - val_accuracy: 0.9268
# Epoch 45/50
# 41/41 [==============================] - 4s 98ms/step - loss: 0.0711 - accuracy: 0.9711 - val_loss: 0.1875 - val_accuracy: 0.9211
# Epoch 46/50
# 41/41 [==============================] - 4s 101ms/step - loss: 0.0719 - accuracy: 0.9729 - val_loss: 0.1782 - val_accuracy: 0.9340
# Epoch 47/50
# 41/41 [==============================] - 4s 102ms/step - loss: 0.0686 - accuracy: 0.9741 - val_loss: 0.2171 - val_accuracy: 0.9139
# Epoch 48/50
# 41/41 [==============================] - 4s 99ms/step - loss: 0.0773 - accuracy: 0.9674 - val_loss: 0.2046 - val_accuracy: 0.9225
# Epoch 49/50
# 41/41 [==============================] - 4s 98ms/step - loss: 0.0549 - accuracy: 0.9809 - val_loss: 0.2476 - val_accuracy: 0.9240
# Epoch 50/50
# 41/41 [==============================] - 4s 102ms/step - loss: 0.0431 - accuracy: 0.9846 - val_loss: 0.2107 - val_accuracy: 0.9254
# 22/22 [==============================] - 5s 97ms/step
# Confusion Matrix:
#  [[176   1   0   0]
#  [  2 184   0   0]
#  [  0   0 152  23]
#  [  0   0  26 133]]
# Accuracy: 0.9253945480631277
