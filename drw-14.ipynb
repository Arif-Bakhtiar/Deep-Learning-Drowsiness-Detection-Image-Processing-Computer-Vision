# %%
import tensorflow as tf
from tensorflow.keras.preprocessing.image import ImageDataGenerator , load_img, img_to_array, array_to_img
from keras.datasets import mnist
import os
from sklearn.model_selection import train_test_split
from sklearn.preprocessing import LabelBinarizer
import matplotlib.pyplot as plt
import numpy as np
import seaborn as sns
from sklearn.metrics import confusion_matrix, auc, roc_curve
from tensorflow.keras.applications import InceptionResNetV2  # Use Inception-ResNetV2
from tensorflow.keras.models import Sequential
from tensorflow.keras.layers import Dense, GlobalAveragePooling2D, Dropout

# %%
# Check GPU availability
print(tf.test.is_gpu_available())
print(tf.config.list_physical_devices('GPU'))
# Out:
# True
# [PhysicalDevice(name='/physical_device:GPU:0', device_type='GPU')]

# %%
# Load the dataset and visualize images
labels = os.listdir("/kaggle/input/augmented-dataset-drowsiness-detection/train")

# %%
# Load the data using ImageDataGenerator
datagen = ImageDataGenerator(
    rescale=1./255,
    validation_split=0.2,
    zoom_range=0.2,
    horizontal_flip=True,
    rotation_range=30
)

# %%
# Load the dataset and split into training and testing sets
directory = "/kaggle/input/augmented-dataset-drowsiness-detection/train"
target_size = (80, 80)
batch_size = 11600 # Adjust batch size as needed

# Load the dataset and split into training and testing sets
data = datagen.flow_from_directory(
    directory,
    target_size=target_size,
    batch_size=batch_size,  # Specify batch size here
    class_mode='categorical',
    subset='training'
)

# Split the data into training and testing sets
x, y = data.next()
x_train, x_test, y_train, y_test = train_test_split(x, y, test_size=0.2, random_state=42)

# Encode the labels using one-hot encoding
label_bin = LabelBinarizer()
y_train = label_bin.fit_transform(y_train)
y_test = label_bin.transform(y_test)
# Out:
# Found 11600 images belonging to 4 classes.

# %%
# Create the Inception-ResNetV2 base model
base_model = InceptionResNetV2(weights='imagenet', include_top=False, input_shape=(80, 80, 3))

# %%
# Add custom layers for classification on top of the base model
model = Sequential([
    base_model,
    GlobalAveragePooling2D(),
    Dense(64, activation='relu'),
    Dropout(0.5),
    Dense(4, activation='sigmoid')
])

# %%
# Freeze the layers in the base model
for layer in base_model.layers:
    layer.trainable = False

# %%
# Compile the model
optimizer = tf.keras.optimizers.Adam(learning_rate=0.001)
model.compile(loss="categorical_crossentropy", metrics=["accuracy"], optimizer=optimizer)
model.summary()
# Out:
# Model: "sequential_1"
# _________________________________________________________________
#  Layer (type)                Output Shape              Param #
# =================================================================
#  inception_resnet_v2 (Functi  (None, 1, 1, 1536)       54336736
#  onal)
#
#  global_average_pooling2d_1   (None, 1536)             0
#  (GlobalAveragePooling2D)
#
#  dense_2 (Dense)             (None, 64)                98368
#
#  dropout_1 (Dropout)         (None, 64)                0
#
#  dense_3 (Dense)             (None, 4)                 260
#
# =================================================================
# Total params: 54,435,364
# Trainable params: 98,628
# Non-trainable params: 54,336,736
# _________________________________________________________________

# %%
# Train the model
hist = model.fit(x_train, y_train, epochs=110, validation_data=(x_test, y_test), batch_size=200)  # Specify batch size here
# Out:
# Epoch 1/110
# 47/47 [==============================] - 23s 184ms/step - loss: 0.7275 - accuracy: 0.6776 - val_loss: 0.4060 - val_accuracy: 0.7892
# Epoch 2/110
# 47/47 [==============================] - 5s 98ms/step - loss: 0.4442 - accuracy: 0.7717 - val_loss: 0.3769 - val_accuracy: 0.7970
# Epoch 3/110
# 47/47 [==============================] - 4s 91ms/step - loss: 0.4006 - accuracy: 0.7946 - val_loss: 0.3608 - val_accuracy: 0.8125
# Epoch 4/110
# 47/47 [==============================] - 5s 97ms/step - loss: 0.3771 - accuracy: 0.8051 - val_loss: 0.3619 - val_accuracy: 0.8009
# Epoch 5/110
# 47/47 [==============================] - 4s 87ms/step - loss: 0.3624 - accuracy: 0.8107 - val_loss: 0.3510 - val_accuracy: 0.8078
# Epoch 6/110
# 47/47 [==============================] - 5s 98ms/step - loss: 0.3509 - accuracy: 0.8188 - val_loss: 0.3497 - val_accuracy: 0.8039
# Epoch 7/110
# 47/47 [==============================] - 5s 98ms/step - loss: 0.3340 - accuracy: 0.8255 - val_loss: 0.3464 - val_accuracy: 0.8091
# Epoch 8/110
# 47/47 [==============================] - 5s 98ms/step - loss: 0.3310 - accuracy: 0.8325 - val_loss: 0.3571 - val_accuracy: 0.8043
# Epoch 9/110
# 47/47 [==============================] - 4s 88ms/step - loss: 0.3187 - accuracy: 0.8327 - val_loss: 0.3383 - val_accuracy: 0.8121
# Epoch 10/110
# 47/47 [==============================] - 4s 88ms/step - loss: 0.3051 - accuracy: 0.8434 - val_loss: 0.3484 - val_accuracy: 0.8095
# Epoch 11/110
# 47/47 [==============================] - 4s 89ms/step - loss: 0.3075 - accuracy: 0.8390 - val_loss: 0.3375 - val_accuracy: 0.8147
# Epoch 12/110
# 47/47 [==============================] - 5s 98ms/step - loss: 0.2951 - accuracy: 0.8514 - val_loss: 0.3363 - val_accuracy: 0.8142
# Epoch 13/110
# 47/47 [==============================] - 4s 87ms/step - loss: 0.2989 - accuracy: 0.8494 - val_loss: 0.3494 - val_accuracy: 0.8155
# Epoch 14/110
# 47/47 [==============================] - 4s 87ms/step - loss: 0.2864 - accuracy: 0.8547 - val_loss: 0.3431 - val_accuracy: 0.8207
# Epoch 15/110
# 47/47 [==============================] - 4s 87ms/step - loss: 0.2742 - accuracy: 0.8546 - val_loss: 0.3459 - val_accuracy: 0.8091
# Epoch 16/110
# 47/47 [==============================] - 5s 98ms/step - loss: 0.2811 - accuracy: 0.8528 - val_loss: 0.3472 - val_accuracy: 0.8112
# Epoch 17/110
# 47/47 [==============================] - 4s 87ms/step - loss: 0.2818 - accuracy: 0.8531 - val_loss: 0.3527 - val_accuracy: 0.8220
# Epoch 18/110
# 47/47 [==============================] - 5s 101ms/step - loss: 0.2689 - accuracy: 0.8664 - val_loss: 0.3464 - val_accuracy: 0.8151
# Epoch 19/110
# 47/47 [==============================] - 5s 99ms/step - loss: 0.2694 - accuracy: 0.8606 - val_loss: 0.3469 - val_accuracy: 0.8181
# Epoch 20/110
# 47/47 [==============================] - 5s 98ms/step - loss: 0.2606 - accuracy: 0.8659 - val_loss: 0.3484 - val_accuracy: 0.8246
# Epoch 21/110
# 47/47 [==============================] - 4s 87ms/step - loss: 0.2574 - accuracy: 0.8687 - val_loss: 0.3399 - val_accuracy: 0.8233
# Epoch 22/110
# 47/47 [==============================] - 4s 88ms/step - loss: 0.2480 - accuracy: 0.8716 - val_loss: 0.3468 - val_accuracy: 0.8172
# Epoch 23/110
# 47/47 [==============================] - 5s 99ms/step - loss: 0.2453 - accuracy: 0.8755 - val_loss: 0.3562 - val_accuracy: 0.8177
# Epoch 24/110
# 47/47 [==============================] - 5s 98ms/step - loss: 0.2397 - accuracy: 0.8813 - val_loss: 0.3666 - val_accuracy: 0.8164
# Epoch 25/110
# 47/47 [==============================] - 4s 91ms/step - loss: 0.2335 - accuracy: 0.8820 - val_loss: 0.3598 - val_accuracy: 0.8112
# Epoch 26/110
# 47/47 [==============================] - 5s 99ms/step - loss: 0.2372 - accuracy: 0.8786 - val_loss: 0.3550 - val_accuracy: 0.8190
# Epoch 27/110
# 47/47 [==============================] - 5s 98ms/step - loss: 0.2391 - accuracy: 0.8752 - val_loss: 0.3646 - val_accuracy: 0.8207
# Epoch 28/110
# 47/47 [==============================] - 5s 98ms/step - loss: 0.2276 - accuracy: 0.8837 - val_loss: 0.3597 - val_accuracy: 0.8211
# Epoch 29/110
# 47/47 [==============================] - 5s 97ms/step - loss: 0.2176 - accuracy: 0.8919 - val_loss: 0.3690 - val_accuracy: 0.8224
# Epoch 30/110
# 47/47 [==============================] - 4s 87ms/step - loss: 0.2186 - accuracy: 0.8933 - val_loss: 0.3729 - val_accuracy: 0.8207
# Epoch 31/110
# 47/47 [==============================] - 5s 98ms/step - loss: 0.2142 - accuracy: 0.8914 - val_loss: 0.3829 - val_accuracy: 0.8138
# Epoch 32/110
# 47/47 [==============================] - 5s 101ms/step - loss: 0.2212 - accuracy: 0.8874 - val_loss: 0.3754 - val_accuracy: 0.8181
# Epoch 33/110
# 47/47 [==============================] - 4s 88ms/step - loss: 0.2139 - accuracy: 0.8944 - val_loss: 0.3769 - val_accuracy: 0.8203
# Epoch 34/110
# 47/47 [==============================] - 5s 100ms/step - loss: 0.2067 - accuracy: 0.8994 - val_loss: 0.3875 - val_accuracy: 0.8237
# Epoch 35/110
# 47/47 [==============================] - 4s 88ms/step - loss: 0.2047 - accuracy: 0.8986 - val_loss: 0.3892 - val_accuracy: 0.8207
# Epoch 36/110
# 47/47 [==============================] - 4s 89ms/step - loss: 0.1977 - accuracy: 0.9042 - val_loss: 0.3870 - val_accuracy: 0.8211
# Epoch 37/110
# 47/47 [==============================] - 5s 98ms/step - loss: 0.1972 - accuracy: 0.9029 - val_loss: 0.3968 - val_accuracy: 0.8168
# Epoch 38/110
# 47/47 [==============================] - 5s 98ms/step - loss: 0.1923 - accuracy: 0.9039 - val_loss: 0.3954 - val_accuracy: 0.8211
# Epoch 39/110
# 47/47 [==============================] - 4s 91ms/step - loss: 0.1897 - accuracy: 0.9077 - val_loss: 0.4062 - val_accuracy: 0.8284
# Epoch 40/110
# 47/47 [==============================] - 4s 88ms/step - loss: 0.1941 - accuracy: 0.9057 - val_loss: 0.4187 - val_accuracy: 0.8241
# Epoch 41/110
# 47/47 [==============================] - 4s 88ms/step - loss: 0.1868 - accuracy: 0.9069 - val_loss: 0.4292 - val_accuracy: 0.8259
# Epoch 42/110
# 47/47 [==============================] - 5s 98ms/step - loss: 0.1804 - accuracy: 0.9134 - val_loss: 0.4126 - val_accuracy: 0.8168
# Epoch 43/110
# 47/47 [==============================] - 4s 87ms/step - loss: 0.1818 - accuracy: 0.9102 - val_loss: 0.4265 - val_accuracy: 0.8220
# Epoch 44/110
# 47/47 [==============================] - 5s 98ms/step - loss: 0.1712 - accuracy: 0.9184 - val_loss: 0.4223 - val_accuracy: 0.8280
# Epoch 45/110
# 47/47 [==============================] - 5s 97ms/step - loss: 0.1730 - accuracy: 0.9157 - val_loss: 0.4202 - val_accuracy: 0.8181
# Epoch 46/110
# 47/47 [==============================] - 4s 86ms/step - loss: 0.1718 - accuracy: 0.9186 - val_loss: 0.4247 - val_accuracy: 0.8198
# Epoch 47/110
# 47/47 [==============================] - 5s 102ms/step - loss: 0.1653 - accuracy: 0.9195 - val_loss: 0.4224 - val_accuracy: 0.8203
# Epoch 48/110
# 47/47 [==============================] - 4s 87ms/step - loss: 0.1673 - accuracy: 0.9177 - val_loss: 0.4408 - val_accuracy: 0.8194
# Epoch 49/110
# 47/47 [==============================] - 5s 97ms/step - loss: 0.1686 - accuracy: 0.9187 - val_loss: 0.4254 - val_accuracy: 0.8220
# Epoch 50/110
# 47/47 [==============================] - 5s 99ms/step - loss: 0.1629 - accuracy: 0.9223 - val_loss: 0.4288 - val_accuracy: 0.8237
# Epoch 51/110
# 47/47 [==============================] - 5s 98ms/step - loss: 0.1711 - accuracy: 0.9182 - val_loss: 0.4504 - val_accuracy: 0.8155
# Epoch 52/110
# 47/47 [==============================] - 5s 99ms/step - loss: 0.1700 - accuracy: 0.9163 - val_loss: 0.4506 - val_accuracy: 0.8233
# Epoch 53/110
# 47/47 [==============================] - 4s 87ms/step - loss: 0.1604 - accuracy: 0.9202 - val_loss: 0.4544 - val_accuracy: 0.8293
# Epoch 54/110
# 47/47 [==============================] - 4s 90ms/step - loss: 0.1465 - accuracy: 0.9282 - val_loss: 0.4555 - val_accuracy: 0.8216
# Epoch 55/110
# 47/47 [==============================] - 5s 99ms/step - loss: 0.1632 - accuracy: 0.9280 - val_loss: 0.4662 - val_accuracy: 0.8168
# Epoch 56/110
# 47/47 [==============================] - 5s 97ms/step - loss: 0.1534 - accuracy: 0.9275 - val_loss: 0.4731 - val_accuracy: 0.8108
# Epoch 57/110
# 47/47 [==============================] - 5s 98ms/step - loss: 0.1497 - accuracy: 0.9272 - val_loss: 0.4811 - val_accuracy: 0.8276
# Epoch 58/110
# 47/47 [==============================] - 4s 87ms/step - loss: 0.1499 - accuracy: 0.9294 - val_loss: 0.4777 - val_accuracy: 0.8216
# Epoch 59/110
# 47/47 [==============================] - 4s 88ms/step - loss: 0.1554 - accuracy: 0.9268 - val_loss: 0.5073 - val_accuracy: 0.8306
# Epoch 60/110
# 47/47 [==============================] - 5s 98ms/step - loss: 0.1594 - accuracy: 0.9210 - val_loss: 0.4591 - val_accuracy: 0.8220
# Epoch 61/110
# 47/47 [==============================] - 5s 101ms/step - loss: 0.1572 - accuracy: 0.9234 - val_loss: 0.4620 - val_accuracy: 0.8293
# Epoch 62/110
# 47/47 [==============================] - 4s 87ms/step - loss: 0.1609 - accuracy: 0.9210 - val_loss: 0.4504 - val_accuracy: 0.8237
# Epoch 63/110
# 47/47 [==============================] - 4s 88ms/step - loss: 0.1632 - accuracy: 0.9198 - val_loss: 0.4797 - val_accuracy: 0.8220
# Epoch 64/110
# 47/47 [==============================] - 4s 88ms/step - loss: 0.1566 - accuracy: 0.9260 - val_loss: 0.4918 - val_accuracy: 0.8194
# Epoch 65/110
# 47/47 [==============================] - 5s 98ms/step - loss: 0.1488 - accuracy: 0.9270 - val_loss: 0.4963 - val_accuracy: 0.8259
# Epoch 66/110
# 47/47 [==============================] - 5s 99ms/step - loss: 0.1499 - accuracy: 0.9235 - val_loss: 0.4969 - val_accuracy: 0.8233
# Epoch 67/110
# 47/47 [==============================] - 4s 87ms/step - loss: 0.1424 - accuracy: 0.9289 - val_loss: 0.5189 - val_accuracy: 0.8280
# Epoch 68/110
# 47/47 [==============================] - 4s 92ms/step - loss: 0.1351 - accuracy: 0.9330 - val_loss: 0.5189 - val_accuracy: 0.8216
# Epoch 69/110
# 47/47 [==============================] - 5s 98ms/step - loss: 0.1411 - accuracy: 0.9306 - val_loss: 0.5427 - val_accuracy: 0.8297
# Epoch 70/110
# 47/47 [==============================] - 5s 98ms/step - loss: 0.1430 - accuracy: 0.9290 - val_loss: 0.5358 - val_accuracy: 0.8272
# Epoch 71/110
# 47/47 [==============================] - 4s 87ms/step - loss: 0.1362 - accuracy: 0.9332 - val_loss: 0.5676 - val_accuracy: 0.8172
# Epoch 72/110
# 47/47 [==============================] - 5s 98ms/step - loss: 0.1420 - accuracy: 0.9376 - val_loss: 0.5191 - val_accuracy: 0.8228
# Epoch 73/110
# 47/47 [==============================] - 5s 98ms/step - loss: 0.1408 - accuracy: 0.9347 - val_loss: 0.5265 - val_accuracy: 0.8280
# Epoch 74/110
# 47/47 [==============================] - 4s 87ms/step - loss: 0.1343 - accuracy: 0.9369 - val_loss: 0.5796 - val_accuracy: 0.8190
# Epoch 75/110
# 47/47 [==============================] - 4s 88ms/step - loss: 0.1339 - accuracy: 0.9348 - val_loss: 0.5682 - val_accuracy: 0.8224
# Epoch 76/110
# 47/47 [==============================] - 4s 89ms/step - loss: 0.1313 - accuracy: 0.9369 - val_loss: 0.5441 - val_accuracy: 0.8203
# Epoch 77/110
# 47/47 [==============================] - 5s 98ms/step - loss: 0.1323 - accuracy: 0.9378 - val_loss: 0.5508 - val_accuracy: 0.8250
# Epoch 78/110
# 47/47 [==============================] - 4s 87ms/step - loss: 0.1322 - accuracy: 0.9367 - val_loss: 0.5724 - val_accuracy: 0.8138
# Epoch 79/110
# 47/47 [==============================] - 4s 86ms/step - loss: 0.1354 - accuracy: 0.9355 - val_loss: 0.6069 - val_accuracy: 0.8164
# Epoch 80/110
# 47/47 [==============================] - 4s 87ms/step - loss: 0.1324 - accuracy: 0.9332 - val_loss: 0.5818 - val_accuracy: 0.8207
# Epoch 81/110
# 47/47 [==============================] - 4s 88ms/step - loss: 0.1262 - accuracy: 0.9395 - val_loss: 0.5750 - val_accuracy: 0.8185
# Epoch 82/110
# 47/47 [==============================] - 4s 87ms/step - loss: 0.1265 - accuracy: 0.9353 - val_loss: 0.5676 - val_accuracy: 0.8263
# Epoch 83/110
# 47/47 [==============================] - 5s 101ms/step - loss: 0.1170 - accuracy: 0.9423 - val_loss: 0.6108 - val_accuracy: 0.8190
# Epoch 84/110
# 47/47 [==============================] - 4s 87ms/step - loss: 0.1349 - accuracy: 0.9302 - val_loss: 0.5414 - val_accuracy: 0.8151
# Epoch 85/110
# 47/47 [==============================] - 5s 100ms/step - loss: 0.1274 - accuracy: 0.9370 - val_loss: 0.5854 - val_accuracy: 0.8241
# Epoch 86/110
# 47/47 [==============================] - 4s 87ms/step - loss: 0.1257 - accuracy: 0.9378 - val_loss: 0.5963 - val_accuracy: 0.8181
# Epoch 87/110
# 47/47 [==============================] - 5s 99ms/step - loss: 0.1214 - accuracy: 0.9402 - val_loss: 0.6250 - val_accuracy: 0.8203
# Epoch 88/110
# 47/47 [==============================] - 5s 98ms/step - loss: 0.1298 - accuracy: 0.9356 - val_loss: 0.5948 - val_accuracy: 0.8177
# Epoch 89/110
# 47/47 [==============================] - 4s 88ms/step - loss: 0.1188 - accuracy: 0.9430 - val_loss: 0.5957 - val_accuracy: 0.8168
# Epoch 90/110
# 47/47 [==============================] - 4s 91ms/step - loss: 0.1256 - accuracy: 0.9376 - val_loss: 0.5923 - val_accuracy: 0.8224
# Epoch 91/110
# 47/47 [==============================] - 5s 99ms/step - loss: 0.1156 - accuracy: 0.9419 - val_loss: 0.5876 - val_accuracy: 0.8121
# Epoch 92/110
# 47/47 [==============================] - 4s 87ms/step - loss: 0.1218 - accuracy: 0.9404 - val_loss: 0.6881 - val_accuracy: 0.8172
# Epoch 93/110
# 47/47 [==============================] - 4s 87ms/step - loss: 0.1197 - accuracy: 0.9409 - val_loss: 0.6104 - val_accuracy: 0.8246
# Epoch 94/110
# 47/47 [==============================] - 5s 99ms/step - loss: 0.1248 - accuracy: 0.9388 - val_loss: 0.5590 - val_accuracy: 0.8164
# Epoch 95/110
# 47/47 [==============================] - 4s 87ms/step - loss: 0.1162 - accuracy: 0.9439 - val_loss: 0.5615 - val_accuracy: 0.8220
# Epoch 96/110
# 47/47 [==============================] - 4s 88ms/step - loss: 0.1237 - accuracy: 0.9365 - val_loss: 0.5843 - val_accuracy: 0.8267
# Epoch 97/110
# 47/47 [==============================] - 5s 99ms/step - loss: 0.1145 - accuracy: 0.9408 - val_loss: 0.6549 - val_accuracy: 0.8203
# Epoch 98/110
# 47/47 [==============================] - 5s 102ms/step - loss: 0.1128 - accuracy: 0.9418 - val_loss: 0.5967 - val_accuracy: 0.8241
# Epoch 99/110
# 47/47 [==============================] - 4s 87ms/step - loss: 0.1158 - accuracy: 0.9411 - val_loss: 0.6095 - val_accuracy: 0.8211
# Epoch 100/110
# 47/47 [==============================] - 5s 98ms/step - loss: 0.1223 - accuracy: 0.9403 - val_loss: 0.6393 - val_accuracy: 0.8181
# Epoch 101/110
# 47/47 [==============================] - 4s 87ms/step - loss: 0.1167 - accuracy: 0.9434 - val_loss: 0.6116 - val_accuracy: 0.8276
# Epoch 102/110
# 47/47 [==============================] - 4s 87ms/step - loss: 0.1203 - accuracy: 0.9414 - val_loss: 0.6719 - val_accuracy: 0.8155
# Epoch 103/110
# 47/47 [==============================] - 5s 99ms/step - loss: 0.1190 - accuracy: 0.9449 - val_loss: 0.6035 - val_accuracy: 0.8138
# Epoch 104/110
# 47/47 [==============================] - 4s 88ms/step - loss: 0.1190 - accuracy: 0.9460 - val_loss: 0.6650 - val_accuracy: 0.8194
# Epoch 105/110
# 47/47 [==============================] - 5s 103ms/step - loss: 0.1045 - accuracy: 0.9469 - val_loss: 0.6881 - val_accuracy: 0.8211
# Epoch 106/110
# 47/47 [==============================] - 5s 99ms/step - loss: 0.1049 - accuracy: 0.9468 - val_loss: 0.6945 - val_accuracy: 0.8112
# Epoch 107/110
# 47/47 [==============================] - 4s 88ms/step - loss: 0.1062 - accuracy: 0.9482 - val_loss: 0.7008 - val_accuracy: 0.8246
# Epoch 108/110
# 47/47 [==============================] - 4s 89ms/step - loss: 0.1045 - accuracy: 0.9496 - val_loss: 0.6296 - val_accuracy: 0.8190
# Epoch 109/110
# 47/47 [==============================] - 5s 98ms/step - loss: 0.1166 - accuracy: 0.9418 - val_loss: 0.6810 - val_accuracy: 0.8211
# Epoch 110/110
# 47/47 [==============================] - 5s 98ms/step - loss: 0.1174 - accuracy: 0.9426 - val_loss: 0.6626 - val_accuracy: 0.8216

# %%
# Save the model
model.save("drowsiness_inceptionv4.h5")
model.save("drowsiness_inceptionv4.model")

# %%
# Plot accuracy and loss
accuracy = hist.history['accuracy']
val_accuracy = hist.history['val_accuracy']
loss = hist.history['loss']
val_loss = hist.history['val_loss']
epochs = range(len(accuracy))

plt.plot(epochs, accuracy, "b", label="training accuracy")
plt.plot(epochs, val_accuracy, "r", label="validation accuracy")
plt.xlabel('Epochs')
plt.ylabel('Accuracy')
plt.title('Training & Validation Accuracy')
plt.legend()
plt.show()

# %%
plt.plot(epochs, loss, "b", label="training loss")
plt.plot(epochs, val_loss, "r", label="validation loss")
plt.xlabel('Epochs')
plt.ylabel('Loss')
plt.title('Training & Validation Loss')
plt.legend()
plt.show()

# %%
# Make predictions and evaluate the model
y_true = np.argmax(y_test, axis=1)
y_pred = model.predict(x_test)
y_pred_classes = np.argmax(y_pred, axis=1)
# Out:
# 73/73 [==============================] - 6s 29ms/step

# %%
# Confusion Matrix
confusion_mtx = confusion_matrix(y_true, y_pred_classes)

# Plot Confusion Matrix
plt.figure(figsize=(8, 6))
sns.heatmap(confusion_mtx, annot=True, fmt='d', cmap='Blues')
plt.xlabel('Predicted')
plt.ylabel('True')
plt.show()

# %%
# Print the confusion matrix
print("Confusion Matrix:\n", confusion_mtx)
# Out:
# Confusion Matrix:
#  [[568   3   0   0]
#  [ 30 547   0   0]
#  [  1   0 394 183]
#  [  0   1 218 375]]

# %%
# Accuracy Score
accuracy = np.sum(y_true == y_pred_classes) / len(y_true)
print("Accuracy:", accuracy)
# Out:
# Accuracy: 0.8120689655172414

# %%
# Classification Report
from sklearn.metrics import classification_report
class_report = classification_report(y_true, y_pred_classes, target_names=labels)
print("Classification Report:\n", class_report)
# Out:
# Classification Report:
#                precision    recall  f1-score   support
#
#       Closed       0.95      0.99      0.97       571
#         Open       0.99      0.95      0.97       577
#         yawn       0.64      0.68      0.66       578
#      no_yawn       0.67      0.63      0.65       594
#
#     accuracy                           0.81      2320
#    macro avg       0.81      0.81      0.81      2320
# weighted avg       0.81      0.81      0.81      2320

# %%
# Compute ROC curves and AUC for each class
n_classes = 4
fpr = dict()
tpr = dict()

roc_auc = dict()

for i in range(n_classes):
    fpr[i], tpr[i], _ = roc_curve(y_test[:, i], y_pred[:, i])
    roc_auc[i] = auc(fpr[i], tpr[i])

# Plot the ROC curves for each class
plt.figure(figsize=(8, 6))
for i in range(n_classes):
    plt.plot(fpr[i], tpr[i], lw=2, label='Class {} (AUC = {:.2f})'.format(i, roc_auc[i]))

plt.plot([0, 1], [0, 1], color='navy', lw=2, linestyle='--')
plt.xlim([0.0, 1.0])
plt.ylim([0.0, 1.05])
plt.xlabel('False Positive Rate')
plt.ylabel('True Positive Rate')
plt.title('Receiver Operating Characteristic (ROC) Curve')
plt.legend(loc='lower right')
plt.show()
