# %%
import tensorflow as tf
from tensorflow.keras.preprocessing.image import ImageDataGenerator
import os
from sklearn.model_selection import train_test_split
from sklearn.preprocessing import LabelBinarizer
import matplotlib.pyplot as plt
import numpy as np
import seaborn as sns
from sklearn.metrics import confusion_matrix, auc, roc_curve
from tensorflow.keras.applications import InceptionResNetV2  # Use Inception-ResNetV2
from tensorflow.keras.models import Sequential
from tensorflow.keras.layers import Dense, GlobalAveragePooling2D, Dropout

# %%
# Check GPU availability
print(tf.test.is_gpu_available())
print(tf.config.list_physical_devices('GPU'))

# Load the dataset and visualize images
labels = os.listdir("/kaggle/input/drowsiness-dataset/train")

# Load the data using ImageDataGenerator
datagen = ImageDataGenerator(
    rescale=1./255,
    validation_split=0.2,
    zoom_range=0.2,
    horizontal_flip=True,
    rotation_range=30
)

# Load the dataset and split into training and testing sets
directory = "../input/drowsiness-dataset/train"
target_size = (240, 240)
batch_size = 4000  # Adjust batch size as needed

# Load the dataset and split into training and testing sets
data = datagen.flow_from_directory(
    directory,
    target_size=target_size,
    batch_size=batch_size,  # Specify batch size here
    class_mode='categorical',
    subset='training'
)

# Split the data into training and testing sets
x, y = data.next()
x_train, x_test, y_train, y_test = train_test_split(x, y, test_size=0.2, random_state=42)

# Encode the labels using one-hot encoding
label_bin = LabelBinarizer()
y_train = label_bin.fit_transform(y_train)
y_test = label_bin.transform(y_test)
# Out:
# True
# [PhysicalDevice(name='/physical_device:GPU:0', device_type='GPU')]
# Found 2321 images belonging to 4 classes.

# %%
# Create the Inception-ResNetV2 base model
base_model = InceptionResNetV2(weights='imagenet', include_top=False, input_shape=(240, 240, 3))

# %%
# Add custom layers for classification on top of the base model
model = Sequential([
    base_model,
    GlobalAveragePooling2D(),
    Dense(64, activation='relu'),
    Dropout(0.5),
    Dense(4, activation='sigmoid')
])

# %%
# Freeze the layers in the base model
for layer in base_model.layers:
    layer.trainable = False

# %%
# Compile the model
optimizer = tf.keras.optimizers.Adam(learning_rate=0.001)
model.compile(loss="categorical_crossentropy", metrics=["accuracy"], optimizer=optimizer)
model.summary()

# Train the model
hist = model.fit(x_train, y_train, epochs=100, validation_data=(x_test, y_test), batch_size=45)  # Specify batch size here


# Save the model
model.save("drowsiness_inceptionv3.h5")
model.save("drowsiness_inceptionv3.model")

# Plot accuracy and loss
accuracy = hist.history['accuracy']
val_accuracy = hist.history['val_accuracy']
loss = hist.history['loss']
val_loss = hist.history['val_loss']
epochs = range(len(accuracy))

plt.plot(epochs, accuracy, "b", label="training accuracy")
plt.plot(epochs, val_accuracy, "r", label="validation accuracy")
plt.xlabel('Epochs')
plt.ylabel('Accuracy')
plt.title('Training & Validation Accuracy')
plt.legend()
plt.show()


plt.plot(epochs, loss, "b", label="training loss")
plt.plot(epochs, val_loss, "r", label="validation loss")
plt.xlabel('Epochs')
plt.ylabel('Loss')
plt.title('Training & Validation Loss')
plt.legend()
plt.show()


# Make predictions and evaluate the model
y_true = np.argmax(y_test, axis=1)
y_pred = model.predict(x_test)
y_pred_classes = np.argmax(y_pred, axis=1)

# Confusion Matrix
confusion_mtx = confusion_matrix(y_true, y_pred_classes)


# Plot Confusion Matrix
plt.figure(figsize=(8, 6))
sns.heatmap(confusion_mtx, annot=True, fmt='d', cmap='Blues')
plt.xlabel('Predicted')
plt.ylabel('True')
plt.show()

# Print the confusion matrix
print("Confusion Matrix:\n", confusion_mtx)
# Out:
# Model: "sequential_2"
# _________________________________________________________________
#  Layer (type)                Output Shape              Param #
# =================================================================
#  inception_resnet_v2 (Functi  (None, 6, 6, 1536)       54336736
#  onal)
#
#  global_average_pooling2d_2   (None, 1536)             0
#  (GlobalAveragePooling2D)
#
#  dense_4 (Dense)             (None, 64)                98368
#
#  dropout_2 (Dropout)         (None, 64)                0
#
#  dense_5 (Dense)             (None, 4)                 260
#
# =================================================================
# Total params: 54,435,364
# Trainable params: 98,628
# Non-trainable params: 54,336,736
# _________________________________________________________________
# Epoch 1/100
# 42/42 [==============================] - 26s 321ms/step - loss: 0.7175 - accuracy: 0.6460 - val_loss: 0.4165 - val_accuracy: 0.8495
# Epoch 2/100
# 42/42 [==============================] - 9s 209ms/step - loss: 0.4635 - accuracy: 0.7592 - val_loss: 0.3707 - val_accuracy: 0.8022
# Epoch 3/100
# 42/42 [==============================] - 9s 208ms/step - loss: 0.4182 - accuracy: 0.7791 - val_loss: 0.3393 - val_accuracy: 0.8430
# Epoch 4/100
# 42/42 [==============================] - 10s 229ms/step - loss: 0.3784 - accuracy: 0.8200 - val_loss: 0.3317 - val_accuracy: 0.8172
# Epoch 5/100
# 42/42 [==============================] - 9s 207ms/step - loss: 0.3652 - accuracy: 0.8098 - val_loss: 0.3074 - val_accuracy: 0.8731
# Epoch 6/100
# 42/42 [==============================] - 9s 210ms/step - loss: 0.3421 - accuracy: 0.8276 - val_loss: 0.3016 - val_accuracy: 0.8688
# Epoch 7/100
# 42/42 [==============================] - 10s 229ms/step - loss: 0.3339 - accuracy: 0.8324 - val_loss: 0.2898 - val_accuracy: 0.8624
# Epoch 8/100
# 42/42 [==============================] - 10s 229ms/step - loss: 0.3140 - accuracy: 0.8448 - val_loss: 0.2846 - val_accuracy: 0.8645
# Epoch 9/100
# 42/42 [==============================] - 10s 232ms/step - loss: 0.3112 - accuracy: 0.8475 - val_loss: 0.3215 - val_accuracy: 0.8280
# Epoch 10/100
# 42/42 [==============================] - 9s 208ms/step - loss: 0.3187 - accuracy: 0.8281 - val_loss: 0.2872 - val_accuracy: 0.8667
# Epoch 11/100
# 42/42 [==============================] - 10s 230ms/step - loss: 0.2788 - accuracy: 0.8712 - val_loss: 0.2633 - val_accuracy: 0.8731
# Epoch 12/100
# 42/42 [==============================] - 10s 229ms/step - loss: 0
100
# 42/42 [==============================] - 9s 208ms/step - loss: 0.1172 - accuracy: 0.9418 - val_loss: 0.2328 - val_accuracy: 0.9054
# Epoch 84/100
# 42/42 [==============================] - 9s 208ms/step - loss: 0.1080 - accuracy: 0.9542 - val_loss: 0.2160 - val_accuracy: 0.9204
# Epoch 85/100
# 42/42 [==============================] - 10s 228ms/step - loss: 0.1143 - accuracy: 0.9504 - val_loss: 0.2239 - val_accuracy: 0.9032
# Epoch 86/100
# 42/42 [==============================] - 10s 229ms/step - loss: 0.1093 - accuracy: 0.9537 - val_loss: 0.2135 - val_accuracy: 0.9247
# Epoch 87/100
# 42/42 [==============================] - 10s 228ms/step - loss: 0.1178 - accuracy: 0.9461 - val_loss: 0.2336 - val_accuracy: 0.9075
# Epoch 88/100
# 42/42 [==============================] - 10s 228ms/step - loss: 0.1141 - accuracy: 0.9440 - val_loss: 0.2323 - val_accuracy: 0.9075
# Epoch 89/100
# 42/42 [==============================] - 10s 232ms/step - loss: 0.1276 - accuracy: 0.9440 - val_loss: 0.2738 - val_accuracy: 0.9075
# Epoch 93/100
# 42/42 [==============================] - 10s 229ms/step - loss: 0.1177 - accuracy: 0.9494 - val_loss: 0.2158 - val_accuracy: 0.9183
# Epoch 94/100
# 42/42 [==============================] - 9s 228ms/step - loss: 0.1177 - accuracy: 0.9488 - val_loss: 0.2188 - val_accuracy: 0.8989
# Epoch 95/100
# 42/42 [==============================] - 10s 229ms/step - loss: 0.1334 - accuracy: 0.9386 - val_loss: 0.2446 - val_accuracy: 0.9075
# Epoch 96/100
# 42/42 [==============================] - 9s 210ms/step - loss: 0.1005 - accuracy: 0.9580 - val_loss: 0.2360 - val_accuracy: 0.8946
# Epoch 97/100
# 42/42 [==============================] - 10s 229ms/step - loss: 0.1544 - accuracy: 0.9224 - val_loss: 0.2340 - val_accuracy: 0.9054
# Epoch 98/100
# 42/42 [==============================] - 9s 207ms/step - loss: 0.1247 - accuracy: 0.9397 - val_loss: 0.2481 - val_accuracy: 0.9032
# Epoch 99/100
# 42/42 [==============================] - 9s 210ms/step - loss: 0.1173 - accuracy: 0.9461 - val_loss: 0.2178 - val_accuracy: 0.9075
# Epoch 100/100
# 42/42 [==============================] - 10s 230ms/step - loss: 0.1134 - accuracy: 0.9499 - val_loss: 0.2265 - val_accuracy: 0.9118
# 15/15 [==============================] - 7s 122ms/step
# Confusion Matrix:
#  [[114   2   0   0]
#  [  0 115   0   0]
#  [  0   0  88  31]
#  [  0   0   8 107]]

# %%
# Save the model
model.save("drowsiness_inceptionv3.h5")
model.save("drowsiness_inceptionv3.model")

# Plot accuracy and loss
accuracy = hist.history['accuracy']
val_accuracy = hist.history['val_accuracy']
loss = hist.history['loss']
val_loss = hist.history['val_loss']
epochs = range(len(accuracy))

plt.plot(epochs, accuracy, "b", label="training accuracy")
plt.plot(epochs, val_accuracy, "r", label="validation accuracy")
plt.xlabel('Epochs')
plt.ylabel('Accuracy')
plt.title('Training & Validation Accuracy')
plt.legend()
plt.show()


plt.plot(epochs, loss, "b", label="training loss")
plt.plot(epochs, val_loss, "r", label="validation loss")
plt.xlabel('Epochs')
plt.ylabel('Loss')
plt.title('Training & Validation Loss')
plt.legend()
plt.show()


# Make predictions and evaluate the model
y_true = np.argmax(y_test, axis=1)
y_pred = model.predict(x_test)
y_pred_classes = np.argmax(y_pred, axis=1)

# Confusion Matrix
confusion_mtx = confusion_matrix(y_true, y_pred_classes)


# Plot Confusion Matrix
plt.figure(figsize=(8, 6))
sns.heatmap(confusion_mtx, annot=True, fmt='d', cmap='Blues')
plt.xlabel('Predicted')
plt.ylabel('True')
plt.show()

# Print the confusion matrix
print("Confusion Matrix:\n", confusion_mtx)

# %%
# Accuracy Score
accuracy = np.sum(y_true == y_pred_classes) / len(y_true)
print("Accuracy:", accuracy)
# Out:
# Accuracy: 0.9118279569892473

# %%
from sklearn.metrics import classification_report
# Classification Report
class_report = classification_report(y_true, y_pred_classes, target_names=labels)
print("Classification Report:\n", class_report)
# Out:
# Classification Report:
#                precision    recall  f1-score   support
#
#       Closed       1.00      0.98      0.99       116
#         Open       0.98      1.00      0.99       115
#         yawn       0.92      0.74      0.82       119
#      no_yawn       0.78      0.93      0.85       115
#
#     accuracy                           0.91       465
#    macro avg       0.92      0.91      0.91       465
# weighted avg       0.92      0.91      0.91       465

# %%
# Compute ROC curves and AUC for each class
n_classes = 4
fpr = dict()
tpr = dict()
roc_auc = dict()

for i in range(n_classes):
    fpr[i], tpr[i], _ = roc_curve(y_test[:, i], y_pred[:, i])
    roc_auc[i] = auc(fpr[i], tpr[i])

# Plot the ROC curves for each class
plt.figure(figsize=(8, 6))
for i in range(n_classes):
    plt.plot(fpr[i], tpr[i], lw=2, label='Class {} (AUC = {:.2f})'.format(i, roc_auc[i]))

plt.plot([0, 1], [0, 1], color='navy', lw=2, linestyle='--')
plt.xlim([0.0, 1.0])
plt.ylim([0.0, 1.05])
plt.xlabel('False Positive Rate')
plt.ylabel('True Positive Rate')
plt.title('Receiver Operating Characteristic (ROC) Curve')
plt.legend(loc='lower right')
plt.show()
