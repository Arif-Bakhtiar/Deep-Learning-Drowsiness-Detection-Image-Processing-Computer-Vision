# %%
import tensorflow
from tensorflow.keras.applications import InceptionV3
from tensorflow.keras.models import Model
from tensorflow.keras.layers import Dropout,Input,Flatten,Dense,MaxPooling2D
from tensorflow.keras.preprocessing.image import ImageDataGenerator

# %%
import numpy as np # linear algebra
import pandas as pd # data processing, CSV file I/O (e.g. pd.read_csv)
import os
import cv2
import matplotlib.pyplot as plt

# %%
from keras.preprocessing.image import ImageDataGenerator

# %% [markdown]
# # Building CNN Model:

# %%
tensorflow.test.is_gpu_available()
# Out:
# True

# %%
tensorflow.config.list_physical_devices('GPU')
# Out:
# [PhysicalDevice(name='/physical_device:GPU:0', device_type='GPU')]

# %%
labels = os.listdir("../input/drowsiness-dataset/train")

# %%
labels
# Out:
# ['Closed', 'Open', 'yawn', 'no_yawn']

# %%
plt.imshow(plt.imread("../input/drowsiness-dataset/train/Closed/_2.jpg"))

# %%
a = plt.imread("../input/drowsiness-dataset/train/yawn/10.jpg")

# %%
a
# Out:
# array([[[ 65,  60,  54],
#         [ 65,  60,  54],
#         [ 65,  60,  54],
#         ...,
#         [254, 254, 254],
#         [255, 255, 255],
#         [255, 255, 255]],
#
#        [[ 65,  60,  54],
#         [ 65,  60,  54],
#         [ 65,  60,  54],
#         ...,
#         [255, 255, 255],
#         [255, 255, 255],
#         [255, 255, 255]],
#
#        [[ 65,  60,  54],
#         [ 65,  60,  54],
#         [ 65,  60,  54],
#         ...,
#         [255, 255, 255],
#         [254, 254, 254],
#         [254, 254, 254]],
#
#        ...,
#
#        [[ 22,  25,  34],
#         [ 22,  25,  34],
#         [ 23,  26,  35],
#         ...,
#         [157, 165, 178],
#         [156, 164, 177],
#         [156, 164, 177]],
#
#        [[ 22,  25,  34],
#         [ 22,  25,  34],
#         [ 23,  26,  35],
#         ...,
#         [155, 163, 176],
#         [155, 163, 176],
#         [155, 163, 176]],
#
#        [[ 22,  25,  34],
#         [ 22,  25,  34],
#         [ 23,  26,  35],
#         ...,
#         [154, 162, 175],
#         [154, 162, 175],
#         [155, 163, 176]]], dtype=uint8)

# %%
a.shape
# Out:
# (480, 640, 3)

# %%
plt.imshow(plt.imread("../input/drowsiness-dataset/train/yawn/5.jpg"))

# %%
train_data_gen = ImageDataGenerator(rescale=1./255, validation_split= 0.2)

# %%
train_data = train_data_gen.flow_from_directory("../input/drowsiness-dataset/train", target_size=(80,80), batch_size=8, class_mode='categorical', subset='training')
# Out:
# Found 2321 images belonging to 4 classes.

# %%
validation_data = train_data_gen.flow_from_directory("../input/drowsiness-dataset/train", target_size=(80,80), batch_size=8, class_mode='categorical', subset= 'validation')
# Out:
# Found 579 images belonging to 4 classes.

# %%
test_data_gen = ImageDataGenerator(rescale=1./255)

# %%
test_data = test_data_gen.flow_from_directory("../input/drowsiness-dataset/train",
                                target_size=(80,80),batch_size=8,class_mode='categorical')
# Out:
# Found 2900 images belonging to 4 classes.

# %%
train_data

# %%
from tensorflow.keras.models import Model
from tensorflow.keras.models import Sequential
from tensorflow.keras.layers import Input, Lambda, Dense, Flatten, Conv2D, MaxPooling2D, Dropout

# %%
model = Sequential()

model.add(Conv2D(256, (3, 3), activation="relu",input_shape=(80,80,3)))
model.add(MaxPooling2D(2, 2))

model.add(Conv2D(128, (3, 3), activation="relu"))
model.add(MaxPooling2D(2, 2))

model.add(Conv2D(64, (3, 3), activation="relu"))
model.add(MaxPooling2D(2, 2))

model.add(Conv2D(32, (3, 3), activation="relu"))
model.add(MaxPooling2D(2, 2))

model.add(Flatten())
model.add(Dropout(0.5))

model.add(Dense(64, activation="relu"))
model.add(Dense(4, activation="softmax"))

model.compile(loss="categorical_crossentropy", metrics=["accuracy"], optimizer="adam")

# %%
model.build(input_shape=(80, 80, 3))

# %%
model.summary()
# Out:
# Model: "sequential"
# _________________________________________________________________
# Layer (type)                 Output Shape              Param #
# =================================================================
# conv2d (Conv2D)              (None, 78, 78, 256)       7168
# _________________________________________________________________
# max_pooling2d (MaxPooling2D) (None, 39, 39, 256)       0
# _________________________________________________________________
# conv2d_1 (Conv2D)            (None, 37, 37, 128)       295040
# _________________________________________________________________
# max_pooling2d_1 (MaxPooling2 (None, 18, 18, 128)       0
# _________________________________________________________________
# conv2d_2 (Conv2D)            (None, 16, 16, 64)        73792
# _________________________________________________________________
# max_pooling2d_2 (MaxPooling2 (None, 8, 8, 64)          0
# _________________________________________________________________
# conv2d_3 (Conv2D)            (None, 6, 6, 32)          18464
# _________________________________________________________________
# max_pooling2d_3 (MaxPooling2 (None, 3, 3, 32)          0
# _________________________________________________________________
# flatten (Flatten)            (None, 288)               0
# _________________________________________________________________
# dropout (Dropout)            (None, 288)               0
# _________________________________________________________________
# dense (Dense)                (None, 64)                18496
# _________________________________________________________________
# dense_1 (Dense)              (None, 4)                 260
# =================================================================
# Total params: 413,220
# Trainable params: 413,220
# Non-trainable params: 0
# _________________________________________________________________

# %%
validation_steps = len(test_data)
validation_steps
# Out:
# 363

# %%
hist = model.fit(train_data, epochs=55, validation_data = test_data, shuffle=True, validation_steps = len(test_data))
# Out:
# Epoch 1/55
# 291/291 [==============================] - 44s 126ms/step - loss: 0.7951 - accuracy: 0.5972 - val_loss: 0.4696 - val_accuracy: 0.7586
# Epoch 2/55
# 291/291 [==============================] - 25s 86ms/step - loss: 0.4515 - accuracy: 0.8005 - val_loss: 0.3632 - val_accuracy: 0.8241
# Epoch 3/55
# 291/291 [==============================] - 25s 86ms/step - loss: 0.3635 - accuracy: 0.8324 - val_loss: 0.4776 - val_accuracy: 0.7828
# Epoch 4/55
# 291/291 [==============================] - 24s 83ms/step - loss: 0.3178 - accuracy: 0.8492 - val_loss: 0.3303 - val_accuracy: 0.8424
# Epoch 5/55
# 291/291 [==============================] - 25s 84ms/step - loss: 0.2873 - accuracy: 0.8707 - val_loss: 0.2679 - val_accuracy: 0.8879
# Epoch 6/55
# 291/291 [==============================] - 25s 86ms/step - loss: 0.2445 - accuracy: 0.8996 - val_loss: 0.2446 - val_accuracy: 0.8986
# Epoch 7/55
# 291/291 [==============================] - 25s 85ms/step - loss: 0.1926 - accuracy: 0.9181 - val_loss: 0.2366 - val_accuracy: 0.9072
# Epoch 8/55
# 291/291 [==============================] - 25s 86ms/step - loss: 0.1816 - accuracy: 0.9293 - val_loss: 0.2054 - val_accuracy: 0.9290
# Epoch 9/55
# 291/291 [==============================] - 25s 85ms/step - loss: 0.1668 - accuracy: 0.9315 - val_loss: 0.1887 - val_accuracy: 0.9321
# Epoch 10/55
# 291/291 [==============================] - 26s 89ms/step - loss: 0.1334 - accuracy: 0.9466 - val_loss: 0.1765 - val_accuracy: 0.9307
# Epoch 11/55
# 291/291 [==============================] - 24s 83ms/step - loss: 0.1240 - accuracy: 0.9505 - val_loss: 0.1596 - val_accuracy: 0.9472
# Epoch 12/55
# 291/291 [==============================] - 25s 86ms/step - loss: 0.1123 - accuracy: 0.9586 - val_loss: 0.2699 - val_accuracy: 0.9272
# Epoch 13/55
# 291/291 [==============================] - 25s 85ms/step - loss: 0.0990 - accuracy: 0.9612 - val_loss: 0.1718 - val_accuracy: 0.9479
# Epoch 14/55
# 291/291 [==============================] - 25s 86ms/step - loss: 0.0851 - accuracy: 0.9638 - val_loss: 0.2049 - val_accuracy: 0.9445
# Epoch 15/55
# 291/291 [==============================] - 24s 83ms/step - loss: 0.0719 - accuracy: 0.9750 - val_loss: 0.1216 - val_accuracy: 0.9555
# Epoch 16/55
# 291/291 [==============================] - 25s 85ms/step - loss: 0.0711 - accuracy: 0.9724 - val_loss: 0.1954 - val_accuracy: 0.9479
# Epoch 17/55
# 291/291 [==============================] - 25s 86ms/step - loss: 0.0598 - accuracy: 0.9759 - val_loss: 0.1317 - val_accuracy: 0.9628
# Epoch 18/55
# 291/291 [==============================] - 25s 86ms/step - loss: 0.0742 - accuracy: 0.9711 - val_loss: 0.1464 - val_accuracy: 0.9552
# Epoch 19/55
# 291/291 [==============================] - 25s 85ms/step - loss: 0.0635 - accuracy: 0.9754 - val_loss: 0.1603 - val_accuracy: 0.9631
# Epoch 20/55
# 291/291 [==============================] - 24s 83ms/step - loss: 0.0441 - accuracy: 0.9858 - val_loss: 0.1596 - val_accuracy: 0.9662
# Epoch 21/55
# 291/291 [==============================] - 25s 85ms/step - loss: 0.0524 - accuracy: 0.9815 - val_loss: 0.1702 - val_accuracy: 0.9566
# Epoch 24/55
# 291/291 [==============================] - 25s 85ms/step - loss: 0.0934 - accuracy: 0.9703 - val_loss: 0.1267 - val_accuracy: 0.9617
# Epoch 25/55
# 291/291 [==============================] - 25s 85ms/step - loss: 0.0411 - accuracy: 0.9875 - val_loss: 0.0976 - val_accuracy: 0.9738
# Epoch 26/55
# 291/291 [==============================] - 25s 87ms/step - loss: 0.0189 - accuracy: 0.9944 - val_loss: 0.1499 - val_accuracy: 0.9617
# Epoch 27/55
# 291/291 [==============================] - 25s 87ms/step - loss: 0.0401 - accuracy: 0.9854 - val_loss: 0.1064 - val_accuracy: 0.9700
# Epoch 28/55
# 291/291 [==============================] - 25s 85ms/step - loss: 0.0381 - accuracy: 0.9875 - val_loss: 0.1096 - val_accuracy: 0.9745
# Epoch 29/55
# 291/291 [==============================] - 25s 85ms/step - loss: 0.0352 - accuracy: 0.9884 - val_loss: 0.1307 - val_accuracy: 0.9710
# Epoch 30/55
# 291/291 [==============================] - 25s 85ms/step - loss: 0.0300 - accuracy: 0.9905 - val_loss: 0.2052 - val_accuracy: 0.9686
# Epoch 31/55
# 291/291 [==============================] - 25s 86ms/step - loss: 0.0202 - accuracy: 0.9927 - val_loss: 0.1472 - val_accuracy: 0.9776
# Epoch 32/55
# 291/291 [==============================] - 25s 86ms/step - loss: 0.0493 - accuracy: 0.9845 - val_loss: 0.0936 - val_accuracy: 0.9807
# Epoch 33/55
# 291/291 [==============================] - 24s 84ms/step - loss: 0.0253 - accuracy: 0.9914 - val_loss: 0.1169 - val_accuracy: 0.9769
# Epoch 34/55
# 291/291 [==============================] - ETA: 0s - loss: 0.0260 - accuracy: 0.9914

# %%
accuracy = hist.history['accuracy']
val_accuracy = hist.history['val_accuracy']
loss = hist.history['loss']
val_loss = hist.history['val_loss']
epochs = range(len(accuracy))

# %%
plt.plot(epochs, accuracy, "b", label="trainning accuracy")
plt.plot(epochs, val_accuracy, "r", label="validation accuracy")
plt.legend()
plt.show()

# %%
plt.plot(epochs, loss, "b", label="trainning loss")
plt.plot(epochs, val_loss, "r", label="validation loss")
plt.legend()
plt.show()

# %%
# model.save("drowiness.h5")
